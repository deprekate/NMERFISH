# %%
from ioMicro import *

# %%
save_folder =r'\\192.168.0.6\bbfishjoy4\CGBB_embryo_4_28_2023\MERFISH_Analysis3'
save_folder =r'\\192.168.0.6\bbfishjoy4extra\MERFISH_AnalysisP56'
save_folder =r'\\192.168.0.6\bbfishjoy4extra\MERFISH_AnalysisP711'
fls = glob.glob(save_folder+os.sep+'decoded*')

# %%
save_folder =r'\\192.168.0.6\bbfishjoy4extra\MERFISH_AnalysisP711'
fov,set_ = 'Conv_zscan__081', '_D16'
dec = decoder_simple(save_folder,fov,set_)
dec.ncols = 3
dec.load_decoded()
apply_fine_drift(dec,plt_val=True)
scoresRefT = get_score_per_color(dec)
# Out:
# Loaded decoded: -3.0874404907226562
# 100%|███████████████████████████████████████████████████████████████████████████████████████| 48/48 [00:07<00:00,  6.51it/s]

# %%
get_score_withRef(dec,scoresRef,plt_val=True,gene=None,iSs = None)
dec.th=-1.5
plot_statistics(dec)

# %%
# #'Sall1' in dec.gns_names

# Z: H97 >> H1
# Z: H98>> H2
# Z: H99>> H3
# Z: H100>>H4
# Z: H101>>H5
# Z: H102>>H6
# Y: H102>>H7
# Y: H104>>H8
# Y: H105>>H9
# V: H106 >>H10
# V: H107>> H11
# V: H108>>H12
# V: H109>> H13
# V: H06 
# Hybridizations and genes are listed below:
# H1: ['Spi1', 'Runx2', 'Ptprc'],
# H2: ['Sox10', 'Irf8', 'Sall1'],
# H3:  ['Runx1', 'Aif1', 'Sall3'],
# H4: ['Cx3cr1', 'Chat', 'Mrc2'],
# H5: ['Mef2c', 'Dcx', 'Runx3'],
# H6: ['Cldn5', 'Fxyd7', 'Itgam'],
# H7: ['Tnc', 'Slc17a6', 'Tgfb2'],
# H8: ['Lyve1', 'Stmn2', 'Mki67'],
# H9: ['Spp1', 'Vtn', 'Olig1'],
# H10:  ['Olig2', '', 'Agt'],
# H11: ['Gfap', '', 'Cnr1'],
# H12: ['Neurog2', '', 'Lhx9'],
# H13: ['Kcnc2', '', 'Nnat']],

# %%
icds,ncds = np.unique(dec.icodesN[dec.scoreA>dec.th],return_counts=True)

# %%
dec.gns_names[np.argsort(ncds)[::-1]]
# Out:
# array(['Dlk1', 'Vim', 'Igf2', 'Eln', 'Marcks', 'E2f1', 'Htr3a', 'Tnnt1',
#        'Xist', 'Pkd2l1', 'Timp3', 'Sox4', 'Atp2b4', 'Tnnt3', 'Tek',
#        'Trex1', 'Ptbp1', 'Vps13c', 'Itpr2', 'Tpi1', 'Tmem132c', 'Pdgfra',
#        'Tjap1', 'Laptm5', 'Zfp36l1', 'Hoxa5', 'Wdr17', 'Tnc', 'Tsc22d1',
#        'Prok2', 'Kctd12', 'Trps1', 'Zic1', 'Zeb2', 'Tcf4', 'Mfap4',
#        'Ncapd2', 'Notch3', 'Tmem119', 'Mybl2', 'Tfap2c', 'Tanc1',
#        'Rnf152', 'Tacr1', 'Gm2026', 'Iqub', 'Plxnb3', 'Chat', 'Dbp',
#        'Uhrf1', 'Tiam1', 'Wipf3', 'Tgfb1', 'Fbxl7', 'Trim9', 'Kcnd2',
#        'Lrrtm4', 'Gja1', 'Yjefn3', 'Kcnab1', 'Tfrc', 'Vwa1', 'Eomes',
#        'Sgcd', 'Gad1', 'Cttnbp2', 'Krt73', 'Camk2b', 'Npff', 'Slc12a5',
#        'Qpct', 'Tardbp', '4833407H14Rik', 'Trpc6', 'Amd2', 'Cspg4',
#        'Orm2', 'Cdhr1', 'Syt2', 'Tcf7l2', 'Tsc22d4', 'Nrxn3', 'Lmod1',
#        'Pramel4', 'Cbln3', 'Trem2', 'Fam163b', 'Serpinf1', 'Pax5', 'Prlr',
#        'Thy1', 'Tmem255a', 'Ccsap', 'Unc5d', 'Tekt5', 'Tbx20', 'Plekhg1',
#        'Kit', 'Sgcz', 'C1qtnf4', 'Tmem158', 'Pde6g', 'E2f8', 'Top2a',
#        'Knl1', 'Tac1', 'Wfikkn2', 'Tmem141', 'Il1b', 'En1', 'St8sia6',
#        'Gm12216', 'Htt', 'Siglece', 'Tnf', 'Pcp4l1', 'Penk', 'Kcnf1',
#        'Gm5083', 'Myc', 'F3', 'Zbtb18', 'Synpr', 'Kcnj6', 'Vipr2', 'Tgm1',
#        'Klk14', 'Lgi2', 'Plch1', 'Unc5c', 'Trhr', 'Nuf2', 'Ucn3', 'Tmpo',
#        'Nptxr', 'Hpca', 'Parvg', 'Bdnf', 'Timp4', 'Trh', 'Slitrk6',
#        'Slit2', 'Unc13b', 'Urah', 'Npas3', 'Nmbr', 'Gata2', 'Slc6a11',
#        'Spock1', 'Ivns1abp', 'Cdc45', 'Coro6', 'Baiap2', 'Nell1', 'Tifab',
#        'Ly6g6e', 'Fcmr', '6330403K07Rik', 'Rgs12', 'Cdh1', 'Jam2',
#        'Syne1', 'Emx1', 'Rhov', 'Synpo2', 'Brinp3', 'Wdr76', 'Vnn1',
#        'Sox11', 'Mia', 'Gpc3', 'Pcbp3', 'Tshz3', 'Pcdh20', 'Ank2', 'Ttk',
#        'Ddc', 'B3gnt7', 'Etnppl', 'Rorb', 'Nhlh2', 'Cd74', 'Ache',
#        'Igfbp2', 'Ramp3', 'Tgtp2', 'Nrp2', 'Pnoc', 'Bmx', 'Fam43a',
#        'Unc13c', 'Id3', 'Pdyn', 'Sema3g', 'Zfp57', 'Trim32', 'Hs3st1',
#        'Mcm5', 'Ahi1', 'A930003A15Rik', 'Ctcf', 'Thsd7b', 'Pola1',
#        'Cd163', 'Kcnip3', 'Nme5', 'Tshz1', 'Rora', 'Tenm2', 'Tle4',
#        'Ube2c', 'Vtn', 'Rln1', 'Oasl2', 'Robo1', 'Dpp10', 'Tnr', 'Tagln',
#        'Drd2', 'Pbx1', 'Slc1a1', 'Tph2', 'Tox', 'Stum', 'Rims4', 'Stmn2',
#        'Camk4', 'Vav1', 'Higd1b', 'Gabbr2', 'Th', 'Tmem252', 'Mafa',
#        'Plk1', 'Icam4', 'Sox17', 'Scube1', 'Capn3', 'Cd14', 'Vipr1',
#        'Lypd6', 'Cdh18', 'Foxm1', 'Slc1a6', 'Dnah11', 'Wfs1', 'Mfge8',
#        'Tmem255b', 'Frmd4a', 'Sall1', 'Negr1', 'blank0075', 'Trim2',
#        'Trpc3', 'Fezf1', 'Btbd11', 'Nov', 'blank0382', 'Enpp2',
#        'blank0128', 'Ppp1r1a', 'Tnn', 'Ms4a6b', 'Cldn3', 'blank0049',
#        'Padi2', 'Dgkh', 'Trp53i11', 'Prom1', 'Ttc16', 'Thrsp', 'Diras1',
#        'Gm11627', 'Nkx2-1', 'Hes1', 'Hk2', 'Sync', 'Kcnc2', 'Slc9a1',
#        'Tmed7', 'Ung', 'Syne2', 'Tsix', 'Kirrel3', 'Gfap', 'Lpl', 'Cdh9',
#        'Tmem163', 'Arpp21', 'Tbr1', 'Tspan15', 'Syt6', 'Tnfrsf12a',
#        'Anln', 'Npsr1', 'Pou3f1', 'Rbm24', 'blank0028', 'Mdk', 'Tyrp1',
#        'Rell1', 'Ms4a7', 'Cpne4', 'Plin2', 'Mtrf1', 'Dgkk', 'Cspg5',
#        'Htr2c', 'Ngb', 'Olig3', 'Tmem108', 'Prss12', 'Dio2', 'Tac2',
#        'Syt11', 'Gadd45g', 'Tcap', 'Necab1', 'Ptpro', 'Ifi27l2a',
#        'Sema6d', 'Kank4', 'Ccl12', 'Kcnc3', 'Tenm1', 'Deup1', 'Col1a2',
#        'Slc6a5', 'Unc13a', 'Ugt8a', 'Cldn10', 'Adgre1', 'Tfap2b',
#        'blank0299', 'Zfpm2', 'Tlr7', 'Tshz2', 'Syp', 'Qk', 'Foxj1', 'Hck',
#        'Ms4a6d', 'Fev', 'Gcnt1', 'Mbp', 'Gpsm1', 'Zmat4', 'Lcn2', 'Wnt8b',
#        'Lmx1a', 'Meis1', 'Miat', 'Dkkl1', 'Id1', 'Ube2k', 'Ccl24',
#        'Rbms3', 'C1qa', 'Sox14', 'Pcdh17', 'Selenop', 'Rasl10a', 'Tpx2',
#        'Lyve1', 'blank0065', 'blank0464', 'Crip2', 'Nos1', 'Sapcd1',
#        'Vip', 'Mef2c', 'Syndig1l', 'Tmem130', 'Usp17la', 'Tubb6', 'Gda',
#        'Slc10a4', 'blank0114', 'Tmem212', 'Nrsn1', 'Acer3', 'Dock2',
#        'Fbxo2', 'blank0245', 'blank0366', 'Lynx1', 'Car8', 'Tmem176b',
#        'Dynlrb2', 'Cdh2', 'Tipin', 'Gabra5', 'blank0339', 'Cks2', 'Mt1',
#        'Rbfox3', 'Dapk2', 'C1qc', 'Fen1', 'Pipox', 'Grin2c', 'Mt3',
#        'Map2', 'Klk6', 'blank0001', 'Gatm', 'blank0361', 'Alox5ap',
#        'Dlx1', 'Tph1', 'blank0118', 'blank0411', 'Cldn5', 'Sox10', 'Cd33',
#        'blank0326', 'Neurod6', 'Tacc3', 'blank0039', 'Serpine2', 'Nek2',
#        'Rpl5', 'Slc17a8', 'Cdk2ap1', 'blank0108', 'Arg1', 'Scrg1',
#        'blank0116', 'Mfng', 'Cnp', 'Casp8ap2', 'Tspan7', 'blank0022',
#        'blank0446', 'Hs3st2', 'blank0163', 'Npnt', 'Folr1', 'Syt1',
#        'blank0331', 'Tmem176a', 'blank0450', 'Npy', 'blank0048', 'Ndst4',
#        'Ubr7', 'blank0341', 'blank0164', 'blank0219', 'Rfx3', 'blank0172',
#        'blank0139', 'Nap1l5', 'Usp1', 'Draxin', 'Angpt1', 'blank0285',
#        'blank0150', 'Adgrl3', 'Fcrls', 'blank0329', 'blank0362', 'Lhfpl3',
#        'Ttc4', 'blank0254', 'blank0332', 'blank0240', 'blank0088',
#        'Tspan13', 'Hopx', 'blank0440', 'Gpx3', 'blank0395', 'blank0091',
#        'blank0435', 'blank0398', 'blank0243', 'blank0307', 'blank0391',
#        'blank0433', 'blank0271', 'blank0462', 'blank0206', 'blank0244',
#        'blank0368', 'blank0461', 'blank0315', 'blank0220', 'blank0337',
#        'blank0388', 'blank0286', 'blank0437', 'blank0274'], dtype='<U13')

# %%
viewer = plot_multigenes(dec,genes=['Lpl','Notch3'],colors=['r','g','b','m','c','y','w'],viewer = None,
                         smin=2,smax=10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 viewer = plot_multigenes(dec,genes=['Lpl','Notch3'],colors=['r','g','b','m','c','y','w'],viewer = None,
#       2                          smin=2,smax=10)
#
# File C:\Scripts\NMERFISH\ioMicro.py:2560, in plot_multigenes(self, genes, colors, smin, smax, viewer, drift, resc)
#    2558     viewer.add_points(Xcms[is_gn][keep_gn][:,:3],size=10,face_color='g',name=gene)
#    2559     return viewer
# -> 2560 def plot_multigenes(self,genes=['Gad1','Sox9'],colors=['r','g','b','m','c','y','w'],smin=3,smax=10,viewer = None,
#    2561                     drift=[0,0,0],resc=[1,1,1]):
#    2562     icodesN,XH_pruned = self.icodesN,self.XH_pruned
#    2563     scoreA=self.scoreA
#
# AttributeError: 'decoder_simple' object has no attribute 'scoreA'

# %%
gene = 'Mki67'
ign = list(dec.gns_names).index(gene)
icol = int(dec.XH_pruned[dec.icodesN==ign][0,0][-2])

# %%
fld = r'\\192.168.0.6\bbfishjoy4\CGBB_embryo_4_28_2023\H104_MER_D16'
fl = fld+os.sep+dec.fov+'.zarr'
if not os.path.exists(fl):
    fld = r'\\192.168.0.7\bbfishmahsa\CGBB_embryo_4_28_2023'+os.sep+os.path.basename(fld)
    fl = fld+os.sep+dec.fov+'.zarr'
im = read_im(fl)[icol]
viewer.add_image(im)
# Out:
# <Image layer 'im' at 0x19e63aeba00>

# %%
#dec.gns_names

# %%
if True:
    if scoresRef is None: scoresRef=scoresRefT
    else: combine_scoresRef(scoresRef,scoresRefT)
    np.save(save_folder+os.sep+'scoresRef.npy',np.array(scoresRef,dtype='object'))

# %%
scoresRef = None

# %%
if type(scoresRef) is str: scoresRef = np.load(scoresRef,allow_pickle=True)
    dec = decoder_simple(save_folder,fov,set_)
    save_fl = dec.save_folder+os.sep+os.sep+tag_save+dec.fov.split('.')[0]+'--'+dec.set_+'.npz'
    if not os.path.exists(save_fl) or force:
        #print(dec.fov,dec.set_)
        try:
            load_segmentation(dec)
            dec.load_decoded()
            if apply_flat:
                apply_flat_field(dec)
            apply_fine_drift(dec,plt_val=plt_val)
            
            #for i in range(3):
            #    apply_brightness_correction(dec)
            #get_scores(dec,plt_val=plt_val)
            dec.ncols=ncols
            get_score_withRef(dec,scoresRef,plt_val=plt_val,gene=None,iSs = None)
            dec.th=th
            #plot_1gene(dec,gene='Gad1',viewer = None)
            if plt_val:
                viewer = plot_multigenes(dec,genes=['Adcy1','Slc1a2','Psap'],colors=['r','g','b','m','c','y','w'],viewer = None,
                                         smin=1,smax=2.5,drift=dec.drift[0],
                                        resc = dec.shape/dec.im_segm_.shape)
                viewer.add_labels(dec.im_segm_);
            if plt_val:
                plot_statistics(dec)
            #print(dec.gns_ordered)

            keepf =  dec.scoreA>dec.th ### keep good score
            icodesf = dec.icodesN[keepf]
            XHfpr = dec.XH_pruned[keepf]
            XHf = np.mean(XHfpr,axis=1)
            if Hths is None:
                ICol = XHfpr[:,:,-2].astype(int)
                Hths = [np.percentile(XHfpr[ICol==icol][:,-3],15) for icol in np.unique(ICol)]
            
            XF = XHf[:,[0,1,2,-5,-4,-3,-2,-1,-1,-1,-1]]
            #zc,xc,yc,bk-7,a-6,habs-5,hn-4,h-3
            XF[:,-1] = dec.scoreA[keepf]
            XF[:,-2] = np.where(keepf)[0]
            mnD = np.mean(np.linalg.norm((XHf[:,np.newaxis]-XHfpr)[:,:,:3],axis=-1),axis=-1)
            XF[:,-3]=mnD
            mnH = np.mean(np.abs((XHf[:,np.newaxis]-XHfpr)[:,:,-3]),axis=-1)
            XF[:,-4]=mnH
            genesf = dec.gns_names[icodesf]
            
            ### deal with smFISH
            for tag_smFISH,gns_smFISH in zip(tags_smFISH,genes_smFISH):
                dec.get_XH_tag(tag=tag_smFISH)#dec.get_XH_tag(tag='Aldh1')
                if apply_flat:
                    Xh = norm_brightness(dec,dec.Xh)
                else:
                    Xh = dec.Xh
                
                tags = [gn+'_smFISH' for gn in gns_smFISH]#['Igfbp_smFISH','Aldh1l1_smFISH','Ptbp1_smFISH']
                
                for icol,tag_gn in enumerate(tags):
                    Xh_ = Xh[Xh[:,-2]==icol]
                    Xh_=Xh_[Xh_[:,-3]>Hths[icol]]
                    Xh_=Xh_[:,[0,1,2,-5,-4,-3,-2,-1,-1,-1,-1]]
                    Xh_[:,-1]=0
                    Xh_[:,-2]=-1
                    Xh_[:,-3]=0
                    Xh_[:,-4]=0
                    XF = np.concatenate([XF,Xh_])
                    genesf = np.concatenate([genesf,[tag_gn]*len(Xh_)])

            cell_id,good = get_cell_id(dec,XF)
            XF_ = np.concatenate([XF[good],cell_id[:,np.newaxis]],axis=-1)
            genesf_ = genesf[good]
            iset = int(dec.set_.split('_set')[-1])
            ifov = int(dec.fov.split('_')[-1].split('.')[0])
            isets = np.array([iset]*len(cell_id))[:,np.newaxis]
            ifovs = np.array([ifov]*len(cell_id))[:,np.newaxis]
            cell_id = cell_id[:,np.newaxis]
            XF_ = np.concatenate([XF[good],cell_id,ifovs,isets],axis=-1)

            get_xyfov(dec)
            XF_ = XF_[:,list(np.arange(XF_.shape[-1]))+[-1,-1]]
            XF_[:,-2:]=dec.xfov,dec.yfov
            header = ['z','x','y','abs_brightness','cor','brightness','color','mean_bightness_variation','mean_distance_variation',
                      'index_from_XH_pruned','score','cell_id','ifov','iset','xfov','yfov']
            icells,vols = np.unique(dec.im_segm_,return_counts=True)
            cms = np.array(ndimage.center_of_mass(np.ones_like(dec.im_segm_),dec.im_segm_,icells))
            icells,vols = np.unique(dec.im_segm_,return_counts=True)
            cms = np.array(ndimage.center_of_mass(np.ones_like(dec.im_segm_),dec.im_segm_,icells))
            cellinfo = cms[:,[0,0,0,1,2,0,0]]
            cellinfo[:,0]=icells
            cellinfo[:,1]=vols
            cellinfo[:,-2:]=dec.xfov,dec.yfov
            header_cells = ['cell_id','volm','zc','xc','yc','xfov','yfov']

            np.savez_compressed(save_fl,XF=XF_.astype(np.float32),
                                genes = genesf_,cellinfo=cellinfo.astype(np.float32),header_cells=header_cells,header=header)
        except:
            print("Failed",dec.fov,dec.set_)
