# %%
import sys
sys.path.append(r'..//')
from ioMicro import *

# %%
ifovs = [264,265,266,275,276,277,279,280,281,
 263,268,267,274,273,278,283,282,311,
 257,269,270,271,272,285,284,309,310,
 256,251,250,249,287,286,307,308,220,305,304,224,226,225,210,211,209,195,196,180,183,180,181,176,
 8,9,13,12,14,42,16,40,41,38,39,45,37,47,46,48,57,56,52]
len(ifovs)
# Out:
# 70

# %%
save_folder =r'\\192.168.0.127\Raw_data\Roy\HumanSVZMER_6_26_2023\MERFISH_Analysis_group2'
fov,set_ = 'Conv_zscan__012', '_set1'
dec = decoder_simple(save_folder,fov,set_)
dec.ncols = 2
dec.load_decoded()
#apply_flat_field(dec)
#apply_fine_drift(dec,plt_val=True)
scoresRefT = get_score_per_color(dec)
get_score_withRef(dec,scoresRef,plt_val=True,gene=None,iSs = None)
dec.th=-1.5
plot_statistics(dec)
# Out:
# Loaded decoded: -0.5781400203704834

# %%
#scoresRef=None

# %%
if True:
    if scoresRef is None: scoresRef=scoresRefT
    else: combine_scoresRef(scoresRef,scoresRefT)
    #pickle.dump(scoresRef,open(save_folder+os.sep+'scoresRef.npy','wb'))
    pickle.dump(scoresRef,open(os.path.dirname(save_folder)+os.sep+'scoresRef.npy','wb'))

# %%
viewer = plot_multigenes(dec,genes=['PTGDS', 'UBC', 'KIF5A'],colors=['r','g','b','m','c','y','w'],viewer = None,smin=2,smax=10)

# %%
im = read_im(r'\\192.168.0.127\Raw_data\Roy\HumanSVZMER_6_26_2023\plate3\P3_PTBP1_PTBP2_REST__set1\Conv_zscan__220.zarr')[0]

# %%
viewer.add_image(im)
# Out:
# <Image layer 'im' at 0x1a8c236cf70>

# %%
#dec.gns_names

# %%
icds,ncds = np.unique(dec.icodesN[dec.scoreA>dec.th],return_counts=True)
print(list(dec.gns_names[icds[np.argsort(ncds)[::-1]]]))
# Out:
# ['PTGDS', 'UBC', 'KIF5A', 'MAG', 'CRYAB', 'SOX9', 'SOX2', 'DPF2', 'CLDND1', 'PNN', 'NLRP4', 'GRINA', 'ZNF853', 'TSPAN7', 'SLC26A3', 'LDHB', 'TAB', 'SMAC', 'SWSAP1', 'RTN1', 'TPD52L1', 'OLIG1', 'AP2B1', 'MSH5', 'SRSF3', 'HTRA2', 'MOG', 'CIAP-2', 'SARAF', 'HIF1', 'STMN4', 'NDRG4', 'HMOX1', 'ERCC4', 'NEUROG2', 'SYTL4', 'MSH6', 'HSP90AB1', 'MAPT', 'NAV1', 'GSDMD', 'NOVA1', 'blank0171', 'RAMP1', 'WSB1', 'EPB41', 'TPT1', 'NRXN1', 'SOX13', 'CLASP1', 'MNX1', 'TMEM2', 'PSD3', 'PTMA', 'UNC5C', 'KIF5B', 'RAPH1', 'APAF1', 'MCF2L2', 'PSMC1', 'LNPEP', 'PCDH9', 'REST', 'EPB41L3', 'ISG15', 'STAT1', 'FAN1', 'MARCKS', 'VDAC3', 'KCNIP4', 'POU3F2', 'HSP90AA1', 'HMOX2', 'FXR1', 'blank0017', 'GAP43', 'SLC44A1', 'XRCC6', 'IFNAR1', 'FADD', 'TCF7L2', 'XPA', 'FLRT1', 'CSNK1E', 'RAB3D', 'blank0129', 'SAT1', 'DLX2', 'TMSB4X', 'blank0157', 'blank0058', 'blank0115', 'PHF21A', 'blank0119', 'IKKA', 'blank0173', 'blank0038', 'HNRNPH1', 'SPDYE2', 'blank0167', 'DLX1', 'blank0103', 'MACF1', 'blank0136', 'blank0121', 'PSMA3', 'blank0079', 'RPN2', 'TREX1', 'blank0113', 'TTLL7', 'MEF2D', 'SMN2', 'SEPT7', 'GRANZYMEB', 'PCSK1N', 'GJA1', 'blank0188', 'NMNAT2', 'VPS13A', 'MEG3', 'blank0005', 'JAK2', 'MSH4', 'PDLIM7', 'blank0028', 'blank0118', 'blank0009', 'blank0124', 'blank0127', 'KRBOX4', 'DUSP14', 'IFI44L', 'RERE', 'blank0031', 'RPL15', 'blank0154', 'SCG5', 'HSPB1', 'COX4I1', 'blank0004', 'blank0013', 'RPLP1', 'LDLRAD3', 'HMGB1', 'blank0068', 'SYN1', 'ZSWIM7', 'blank0018', 'blank0012', 'blank0153', 'RAB27B', 'ZC3HAV1', 'blank0033', 'TMEM106B', 'blank0111', 'TENM2', 'blank0019', 'blank0039', 'FGF2', 'blank0008', 'blank0046', 'blank0185', 'blank0112', 'blank0078', 'blank0003', 'ENPP1', 'blank0055', 'SLX1B', 'blank0177', 'blank0102', 'blank0030', 'blank0050', 'blank0155', 'blank0014', 'blank0131', 'blank0000', 'DCLRE1C', 'blank0106', 'blank0035', 'blank0135', 'blank0128', 'blank0180', 'blank0105', 'blank0117', 'PNKP', 'EIF4A2', 'MED12L', 'blank0126', 'blank0036', 'blank0083', 'blank0010', 'NUMB', 'LUC7L', 'blank0051', 'blank0073', 'blank0178', 'blank0187', 'blank0172', 'blank0084', 'RPS6', 'blank0016', 'blank0158', 'CREB5', 'blank0066', 'blank0076', 'blank0023', 'blank0045', 'TAK1', 'blank0037', 'blank0184', 'blank0183', 'blank0064', 'TNF', 'blank0032', 'blank0125', 'blank0077', 'blank0082', 'blank0063', 'blank0057', 'blank0175', 'blank0107', 'CDC42', 'blank0085', 'blank0022', 'blank0186', 'blank0182', 'blank0122', 'blank0071', 'ATP1B3', 'blank0006', 'blank0087', 'CYBA', 'blank0080', 'blank0011', 'blank0110', 'blank0049', 'blank0176', 'blank0134', 'blank0081', 'NAV2', 'blank0027', 'blank0056', 'blank0181', 'blank0042', 'COX5B', 'IGF1R', 'blank0164', 'blank0054', 'blank0156', 'ERCC5', 'PMS1', 'blank0041', 'PSMA6', 'PKM', 'RYR2', 'DDB2', 'blank0075', 'blank0021', 'blank0133', 'blank0141', 'blank0143', 'LRRC7', 'blank0108', 'blank0132', 'PPIA', 'blank0034', 'MT1X', 'blank0163', 'blank0166', 'blank0162', 'blank0140', 'blank0094', 'blank0092', 'blank0093', 'blank0174', 'blank0159', 'blank0029', 'blank0095', 'blank0020', 'blank0170', 'blank0150', 'blank0169', 'blank0065', 'blank0089', 'blank0088', 'blank0179', 'blank0097', 'blank0116', 'blank0165', 'blank0160', 'blank0070', 'blank0114', 'blank0149', 'blank0120', 'blank0161', 'blank0148', 'blank0069', 'blank0138', 'blank0137', 'blank0100', 'blank0151', 'blank0168', 'blank0152', 'blank0043', 'blank0062']

# %%
#viewer = plot_multigenes(dec,genes=['NEFM','AQP4','CD74','CHMP2A','HTT'],colors=['r','g','b','m','c','y','w'],viewer = None,smin=2,smax=10)
