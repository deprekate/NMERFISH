# %%
import sys
sys.path.append(r'..//')
from ioMicro import *

# %%
sys.path.append(os.path.abspath('Human'))
from workerScope3A_HttHuman_Snonia__06_12_2023 import *

# %%
save_folder =r'\\192.168.0.21\bbfishdc21\HttHuman_Snonia__06_12_2023\MERFISH_Analysis_group1'
fov,set_ = 'Conv_zscan__08', '_set2'
dec = decoder_simple(save_folder,fov,set_)
dec.ncols=2
dec.load_decoded()
# Out:
# Loaded decoded: -0.4553673267364502
# True

# %%
apply_fine_drift(dec,plt_val=True)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 24/24 [00:01<00:00, 15.20it/s]

# %%
scoresRefT = get_score_per_color(dec)
get_score_withRef(dec,scoresRefT,plt_val=True,gene=None,iSs = None,th_min=-10)
dec.th=-1.
plot_statistics(dec)

# %%
icds,ncds = np.unique(dec.icodesN[dec.scoreA>dec.th],return_counts=True)
print(list(np.array(dec.gns_names)[icds[np.argsort(ncds)[::-1]]]))
# Out:
# ['AQP4', 'CD74', 'NEAT1', 'ISG20', 'B2M', 'HIF3A', 'CHMP2A', 'CSF1R', 'HOXA7', 'ATOH8', 'LINC01107', 'DUSP1', 'CBLN2', 'HSPB6', 'CHMP6', 'CLEC5A', 'LPIN1', 'BRIP1', 'HOXD9', 'DSG3', 'MT1E', 'DST', 'CBX5', 'NES', 'MOBP', 'CDK20', 'ACTG1', 'FAM20A', 'CXCL14', 'KPNB1', 'MEPE', 'CRHR2', 'NPAP1', 'HTT', 'MYO18A', 'blank0113', 'BCHE', 'CPLX3', 'NCAM2', 'CHRNA2', 'ABI3BP', 'ISX', 'CETN3', 'GRID2', 'EYA4', 'FTH1', 'AKAP6', 'MRC1', 'blank0057', 'CNTNAP4', 'APBB1IP', 'IPO5', 'ABCB1', 'KCNC2', 'blank0117', 'CP', 'LMNA', 'LBR', 'ADGRV1', 'HOXA5', 'CAPN2', 'blank0137', 'CCDC85A', 'CETN2', 'DACH1', 'LAMA4', 'blank0118', 'COL15A1', 'KLHL1', 'GRIA1', 'blank0070', 'blank0044', 'GSX1', 'CA1', 'HOXD8', 'CSE1L', 'COLEC12', 'blank0002', 'GLIS3', 'DCX', 'blank0131', 'GRM5', 'blank0165', 'ASIC4', 'CEMIP', 'LINC00499', 'GLRA3', 'MAP6D1', 'blank0043', 'HHIPL1', 'KPNA1', 'blank0177', 'LINC01202', 'DOCK8', 'CDH13', 'NRG1', 'blank0123', 'ADARB2', 'blank0032', 'blank0022', 'blank0062', 'IPO9', 'FLT1', 'NMU', 'blank0093', 'CHMP1A', 'ITPR1', 'blank0109', 'blank0068', 'CYP4B1', 'NEFH', 'blank0144', 'CNR1', 'BCAS1', 'ELAVL2', 'blank0039', 'LEMD2', 'CDH3', 'blank0025', 'CBLN1', 'blank0168', 'blank0009', 'blank0106', 'ELAVL4', 'HS6ST3', 'HOXA11', 'blank0182', 'blank0116', 'blank0058', 'MT1G', 'blank0076', 'DCC', 'AHCTF1', 'CCNJL', 'blank0150', 'blank0180', 'blank0035', 'KLF5', 'KCNIP2', 'NUP133
# %%
viewer = plot_multigenes(dec,genes=['AQP4','CD74','NEFM','ISG20','NCAM2','HTT'],colors=['r','g','b','m','c','y','w'],viewer = None,
                         smin=2,smax=20)

# %%
drifts,flds,fov_,fl_ref = np.load(dec.drift_fl,allow_pickle=True)

# %%
flds
# Out:
# ['\\\\192.168.0.21\\bbfishdc21\\HttHuman_Snonia__06_12_2023\\H1_MER2col__set2',
#  '\\\\192.168.0.21\\bbfishdc21\\HttHuman_Snonia__06_12_2023\\P1__Gad1_Nrgn_Aqp4__set2',
#  '\\\\192.168.0.21\\bbfishdc21\\HttHuman_Snonia__06_12_2023\\H2_MER2col__set2',
#  '\\\\192.168.0.21\\bbfishdc21\\HttHuman_Snonia__06_12_2023\\H3_MER2col__set2',
#  '\\\\192.168.0.21\\bbfishdc21\\HttHuman_Snonia__06_12_2023\\H4_MER2col__set2',
#  '\\\\192.168.0.21\\bbfishdc21\\HttHuman_Snonia__06_12_2023\\H5_MER2col__set2',
#  '\\\\192.168.0.21\\bbfishdc21\\HttHuman_Snonia__06_12_2023\\H6_MER2col__set2',
#  '\\\\192.168.0.21\\bbfishdc21\\HttHuman_Snonia__06_12_2023\\H7_MER2col__set2',
#  '\\\\192.168.0.21\\bbfishdc21\\HttHuman_Snonia__06_12_2023\\H8_MER2col__set2',
#  '\\\\192.168.0.21\\bbfishdc21\\HttHuman_Snonia__06_12_2023\\H9_MER2col__set2',
#  '\\\\192.168.0.21\\bbfishdc21\\HttHuman_Snonia__06_12_2023\\H10_MER2col__set2',
#  '\\\\192.168.0.21\\bbfishdc21\\HttHuman_Snonia__06_12_2023\\H11_MER2col__set2',
#  '\\\\192.168.0.21\\bbfishdc21\\HttHuman_Snonia__06_12_2023\\H12_MER2col__set2']

# %%
from dask import array as da
tag = 'MER2col'
drifts,flds,fov_,fl_ref = np.load(dec.drift_fl,allow_pickle=True)
im  = da.concatenate([da.roll(read_im(fld_+os.sep+fov_),drft[0].astype(int),axis=[1,2,3])[np.newaxis]for fld_,drft in zip(flds,drifts)
                                                                         if tag in os.path.basename(fld_)])
import napari
napari.view_image(im)

# %%
import napari
napari.view_image(im)
# Out:
# Viewer(axes=Axes(visible=False, labels=True, colored=True, dashed=False, arrows=True), camera=Camera(center=(0.0, 1499.5, 1499.5), zoom=0.15516666666666665, angles=(0.0, 0.0, 90.0), perspective=0.0, interactive=True), cursor=Cursor(position=(1.0, 1.0, 0.0, 0.0, 0.0), scaled=True, size=1, style=<CursorStyle.STANDARD: 'standard'>), dims=Dims(ndim=5, ndisplay=2, last_used=0, range=((0.0, 12.0, 1.0), (0.0, 3.0, 1.0), (0.0, 37.0, 1.0), (0.0, 3000.0, 1.0), (0.0, 3000.0, 1.0)), current_step=(6, 1, 18, 1500, 1500), order=(0, 1, 2, 3, 4), axis_labels=('0', '1', '2', '3', '4')), grid=GridCanvas(stride=1, shape=(-1, -1), enabled=False), layers=[<Image layer 'im' at 0x1238f366c10>], scale_bar=ScaleBar(visible=False, colored=False, ticks=True, position=<Position.BOTTOM_RIGHT: 'bottom_right'>, font_size=10, unit=None), text_overlay=TextOverlay(visible=False, color=(0.5, 0.5, 0.5, 1.0), font_size=10, position=<TextOverlayPosition.TOP_LEFT: 'top_left'>, text=''), overlays=Overlays(interaction_box=InteractionBox(points=None, show=False, show_handle=False, show_vertices=False, selection_box_drag=None, selection_box_final=None, transform_start=<napari.utils.transforms.transforms.Affine object at 0x000001238D216D90>, transform_drag=<napari.utils.transforms.transforms.Affine object at 0x000001238D216FD0>, transform_final=<napari.utils.transforms.transforms.Affine object at 0x000001238D216AF0>, transform=<napari.utils.transforms.transforms.Affine object at 0x000001238D302070>, allow_new_selection=True, selected_vertex=None)), help='', status='Ready', tooltip=Tooltip(visible=False, text=''), theme='dark', title='napari', mouse_move_callbacks=[<function InteractionBoxMouseBindings.initialize_mouse_events.<locals>.mouse_move at 0x000001238F3B4280>], mouse_drag_callbacks=[<function InteractionBoxMouseBindings.initialize_mouse_events.<locals>.mouse_drag at 0x000001238F3A1700>], mouse_double_click_callbacks=[], mouse_wheel_callbacks=[<function dims_scroll at 0x0000012333684310>], _persisted_mouse_event={}, _mouse_drag_gen={}, _mouse_wheel_gen={}, keymap={'Shift': <function InteractionBoxMouseBindings.initialize_key_events.<locals>.hold_to_lock_aspect_ratio at 0x000001238F3A1310>, 'Control-Shift-R': <function InteractionBoxMouseBindings._reset_active_layer_affine at 0x000001238F3A1E50>, 'Control-Shift-A': <function InteractionBoxMouseBindings._transform_active_layer at 0x000001238F3A1C10>})

# %%
complete = dec.check_is_complete()
#if complete==0 or redo:
dec.get_XH(fov,set_,ncols=2,nbits=12)#number of colors match 
dec.XH = dec.XH[dec.XH[:,-4]>0.25] ### keep the spots that are correlated with the expected PSF for 60X
dec.load_library(lib_fl = lib_fl,nblanks=-1)
# Out:
# Completed
# 100%|██████████████████████████████████████████████████████████████████████████████████| 12/12 [00:17<00:00,  1.49s/it]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 5
#       3 dec.get_XH(fov,set_,ncols=2,nbits=12)#number of colors match
#       4 dec.XH = dec.XH[dec.XH[:,-4]>0.25] ### keep the spots that are correlated with the expected PSF for 60X
# ----> 5 dec.load_library(lib_fl = lib_fl,nblanks=-1)
#
# NameError: name 'lib_fl' is not defined

# %%
#np.unique(dec.XH[:,-1],return_counts=True)
#dec.gns_names

# %%
dec.get_inters(dinstance_th=2,enforce_color=True)# enforce_color=False
dec.get_icodes(nmin_bits=4,method = 'top4',norm_brightness=None,nbits=24,is_unique=True)
# Out:
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]Exception ignored in: <generator object tqdm.__iter__ at 0x00000195BF555120>
# Traceback (most recent call last):
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\tqdm\std.py", line 1209, in __iter__
#     self.n = n
# KeyboardInterrupt:
#   0%|                                                                                            | 0/2 [00:25<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 dec.get_inters(dinstance_th=2,enforce_color=True)# enforce_color=False
#       2 dec.get_icodes(nmin_bits=4,method = 'top4',norm_brightness=None,nbits=24,is_unique=True)
#
# File C:\Scripts\NMERFISH\Human\..\ioMicro.py:2149, in decoder_simple.get_inters(self, dinstance_th, enforce_color)
#    2147         Ts = cKDTree(Xs)
#    2148         res_ = Ts.query_ball_tree(Ts,dinstance_th)
# -> 2149         res += [inds[r] for r in res_]
#    2150 else:
#    2151     XH = self.XH
#
# File C:\Scripts\NMERFISH\Human\..\ioMicro.py:2149, in <listcomp>(.0)
#    2147         Ts = cKDTree(Xs)
#    2148         res_ = Ts.query_ball_tree(Ts,dinstance_th)
# -> 2149         res += [inds[r] for r in res_]
#    2150 else:
#    2151     XH = self.XH
#
# KeyboardInterrupt:

# %%
dec.XH_pruned.shape
# Out:
# (881342, 4, 10)

# %%
save_folder =r'\\192.168.0.21\bbfishdc21\HttHuman_Snonia__06_12_2023\MERFISH_Analysis_group3'
#save_folder =r'\\192.168.0.21\bbfishdc21\HttHuman_Snonia__06_12_2023\MERFISH_Analysis_group6'
#save_folder =r'\\192.168.0.96\bbfish124\HttHuman_Snonia__06_12_2023\MERFISH_Analysis_group5'
fov,set_ = 'Conv_zscan__30', '_set5'
dec = decoder_simple(save_folder,fov,set_)
dec.ncols=2
dec.load_decoded()
apply_fine_drift(dec,plt_val=True)
scoresRefT = get_score_per_color(dec)
get_score_withRef(dec,scoresRefT,plt_val=True,gene=None,iSs = None)
dec.th=-1.5
plot_statistics(dec)
# Out:
# Loaded decoded: -1.067183017730713
# 100%|██████████████████████████████████████████████████████████████████████████████████| 24/24 [00:02<00:00,  8.81it/s]

# %%
viewer = plot_multigenes(dec,genes=['RBFOX1','PLP1','TH'],colors=['r','g','b','m','c','y','w'],viewer = None,
                         smin=2,smax=7)

# %%
icds,ncds = np.unique(dec.icodesN[dec.scoreA>dec.th],return_counts=True)
print(list(np.array(dec.gns_names)[icds[np.argsort(ncds)[::-1]]]))
# Out:
# ['APP', 'SLC17A7', 'ANK2', 'TUBB4A', 'VSNL1', 'RANGAP1', 'RBFOX1', 'SPOCK1', 'OLFM3', 'ATP1B1', 'SNCB', 'SATB2', 'CACNA1A', 'TUBA4A', 'SORT1', 'PLEC', 'CD81', 'RASGRF2', 'CASP7', 'TRPM3', 'STARD13', 'TUBB3', 'PAX6', 'PLP1', 'SLC32A1', 'XPO7', 'RAN', 'PLCH1', 'NUP205', 'TNPO3', 'RANBP3', 'TARDBP', 'SUN1', 'COX7A2L', 'PLA2G4C', 'TAFA2', 'SPTBN4', 'ADGRG1', 'PRKG1', 'RGPD2', 'ROBO1', 'CACNA1D', 'UNC13C', 'CACNA1H', 'SPTA1', 'ZNF385D', 'TUBB', 'TMEM132C', 'SLN', 'STK17B', 'CHAT', 'CD63', 'PLPP6', 'PDGFD', 'CASP10', 'TNC', 'AEBP1', 'SV2C', 'SYNE2', 'BAD', 'NUP54', 'TUBG1', 'POM121L2', 'VPS4B', 'RGPD3', 'SLIT2', 'PDE4B', 'ZNF295-AS1', 'CASP14', 'SLC11A1', 'RAE1', 'ZFPM2', 'PRELID2', 'SUN3', 'CD83', 'BRCA2', 'TUBB2B', 'C1QB', 'PCSK5', 'TMPO', 'TOR1AIP1', 'CASP3', 'APOC1', 'ATP6AP2', 'CCDC8', 'SPTBN2', 'NUP35', 'PDGFRA', 'TH', 'NXT2', 'RANBP3L', 'TPR', 'SMPD4', 'RGPD1', 'RMST', 'PLCXD3', 'SPTBN5', 'PVALB', 'ARL17B', 'THEMIS', 'ANLN', 'RGPD5', 'CASP6', 'SOX6', 'TOR4A', 'XPO4', 'ADAMTSL3', 'TAFA1', 'WNT4', 'NXF1', 'CATALASE', 'PLPP7', 'PIK3CD', 'ATP5G2', 'SLC6A16', 'SUN2', 'PLA2G4A', 'RYR1', 'blank0132', 'P2RY12', 'NUP37', 'PCDH11X', 'SH3RF3', 'PRPH', 'PENK', 'NUP62', 'SEH1L', 'MZT2B', 'RTKN2', 'SETD5', 'C9ORF142', 'PTPRK', 'TUBA3D', 'SHISA6', 'POU6F2', 'PTPRD', 'TYROBP', 'VIP', 'TOR3A', 'NUP155', 'PHLDB3', 'NUP160', 'PRRT4', 'RIT2', 'SOX11', 'SYNE3', 'RPRM', 'BAX', 'POM121L12', 'SLC14A1', 'CGAS', 'TSHZ2', 'NUP58', 'TOR1AIP2', 'blank0100', 'SORL1', 'PLAAT1', 'TMEM43', 'SCML4', 'C1ORF132', 'PPP6R3', 'SHISA9', 'ZNF292', 'SST', 'VCAN', 'blank0046', 'UNC13B', 'blank0035', 'blank0113', 'blank0066', 'CA2', 'SEMA5A', 'blank0086', 'blank0135', 'blank0065', 'TUBA3C', 'blank0008', 'blank0033', 'NUTF2', 'NUP42', 'TRRAP', 'APOO', 'blank0030', 'blank0131', 'VILL', 'blank0130', 'TMEM170A', 'blank0079', 'blank0148', 'SLC6A20', 'blank0133', 'blank0038', 'blank0158', 'blank0165', 'blank0151', 'PNO1', 'blank0107', 'blank0104', 'SCN1A', 'blank0185', 'blank0161', 'blank0178', 'blank0009', 'P4HA3', 'blank0134', 'blank0149', 'blank0124', 'blank0045', 'blank0040', 'blank0019', 'blank0098', 'blank0031', 'RNF219-AS1', 'blank0089', 'VWA8', 'blank0110', 'CHRM5', 'blank0054', 'blank0061', 'blank0162', 'blank0022', 'blank0032', 'blank0147', 'blank0067', 'blank0139', 'blank0181', 'blank0080', 'blank0116', 'blank0043', 'NUP98', 'blank0177', 'blank0145', 'blank0182', 'blank0160', 'PACRGL', 'blank0064', 'blank0036', 'blank0152', 'blank0129', 'blank0007', 'blank0141', 'blank0073', 'blank0078', 'blank0024', 'blank0004', 'blank0096', 'blank0169', 'blank0056', 'blank0039', 'blank0027', 'blank0127', 'blank0058', 'blank0047', 'PTPRT', 'blank0146', 'blank0108', 'blank0018', 'blank0126', 'blank0103', 'blank0167', 'blank0142', 'blank0154', 'blank0000', 'blank0062', 'blank0044', 'blank0175', 'blank0092', 'blank0074', 'blank0012', 'blank0164', 'blank0055', 'blank0076', 'blank0003', 'blank0186', 'UNC13A', 'blank0114', 'blank0052', 'blank0094', 'blank0023', 'blank0097', 'blank0006', 'blank0093', 'blank0150', 'blank0136', 'blank0063', 'blank0137', 'ZFPM2-AS1', 'blank0101', 'POLDIP3', 'blank0084', 'blank0037', 'blank0060', 'blank0159', 'blank0143', 'blank0174', 'blank0144', 'blank0071', 'blank0099', 'blank0029', 'blank0163', 'blank0016', 'blank0041', 'blank0176', 'blank0168', 'blank0115', 'blank0034', 'blank0001', 'blank0140', 'blank0049', 'blank0026', 'blank0072', 'blank0117', 'blank0051', 'blank0075', 'blank0021', 'blank0059', 'blank0183', 'blank0156', 'blank0011', 'blank0112', 'blank0025', 'blank0077', 'blank0125', 'blank0085', 'blank0090', 'blank0119', 'blank0091', 'blank0002', 'blank0005', 'blank0118', 'blank0028', 'blank0070', 'blank0020', 'blank0042', 'blank0138', 'blank0050', 'blank0048', 'blank0017', 'blank0095', 'blank0123', 'blank0013', 'blank0105', 'blank0069', 'blank0087', 'blank0155', 'blank0184', 'blank0128', 'blank0171', 'blank0015', 'blank0010', 'RAP1GAP', 'blank0180', 'blank0172', 'blank0053', 'blank0014', 'blank0102', 'blank0153', 'blank0121', 'blank0083', 'blank00 ...

# %%
#save_folder =r'\\192.168.0.21\bbfishdc21\HttHuman_Snonia__06_12_2023\MERFISH_Analysis_group3'
#fov,set_ = 'Conv_zscan__30', '_set5'
#dec = decoder_simple(save_folder,fov,set_)

# %%
#save_folder =r'\\192.168.0.21\bbfishdc21\HttHuman_Snonia__06_12_2023\MERFISH_Analysis_group5'
save_folder =r'\\192.168.0.96\bbfish124\HttHuman_Snonia__06_12_2023\MERFISH_Analysis_group5'
fov,set_ = 'Conv_zscan__30', '_set5'
dec = decoder_simple(save_folder,fov,set_)
check_image(dec)
# Out:
# Found files for fov: Conv_zscan__30.zarr ['\\\\192.168.0.96\\bbfish124\\HttHuman_Snonia__06_12_2023\\H49_MER2col__set5', '\\\\192.168.0.96\\bbfish124\\HttHuman_Snonia__06_12_2023\\H50_MER2col__set5', '\\\\192.168.0.96\\bbfish124\\HttHuman_Snonia__06_12_2023\\H51_MER2col__set5', '\\\\192.168.0.96\\bbfish124\\HttHuman_Snonia__06_12_2023\\H52_MER2col__set5', '\\\\192.168.0.96\\bbfish124\\HttHuman_Snonia__06_12_2023\\H53_MER2col__set5', '\\\\192.168.0.96\\bbfish124\\HttHuman_Snonia__06_12_2023\\H54_MER2col__set5', '\\\\192.168.0.96\\bbfish124\\HttHuman_Snonia__06_12_2023\\H55_MER2col__set5', '\\\\192.168.0.96\\bbfish124\\HttHuman_Snonia__06_12_2023\\H56_MER2col__set5', '\\\\192.168.0.96\\bbfish124\\HttHuman_Snonia__06_12_2023\\H57_MER2col__set5', '\\\\192.168.0.96\\bbfish124\\HttHuman_Snonia__06_12_2023\\H58_MER2col__set5', '\\\\192.168.0.96\\bbfish124\\HttHuman_Snonia__06_12_2023\\H59_MER2col__set5', '\\\\192.168.0.96\\bbfish124\\HttHuman_Snonia__06_12_2023\\H60_MER2col__set5']
# Viewer(axes=Axes(visible=False, labels=True, colored=True, dashed=False, arrows=True), camera=Camera(center=(0.0, 1499.5, 1499.5), zoom=0.3663833333333333, angles=(0.0, 0.0, 90.0), perspective=0.0, interactive=True), cursor=Cursor(position=(1.0, 1.0, 0.0, 0.0, 0.0), scaled=True, size=1, style=<CursorStyle.STANDARD: 'standard'>), dims=Dims(ndim=5, ndisplay=2, last_used=0, range=((0.0, 12.0, 1.0), (0.0, 3.0, 1.0), (0.0, 37.0, 1.0), (0.0, 3000.0, 1.0), (0.0, 3000.0, 1.0)), current_step=(6, 1, 18, 1500, 1500), order=(0, 1, 2, 3, 4), axis_labels=('0', '1', '2', '3', '4')), grid=GridCanvas(stride=1, shape=(-1, -1), enabled=False), layers=[<Image layer 'im' at 0x1d21bc63700>], scale_bar=ScaleBar(visible=False, colored=False, ticks=True, position=<Position.BOTTOM_RIGHT: 'bottom_right'>, font_size=10, unit=None), text_overlay=TextOverlay(visible=False, color=(0.5, 0.5, 0.5, 1.0), font_size=10, position=<TextOverlayPosition.TOP_LEFT: 'top_left'>, text=''), overlays=Overlays(interaction_box=InteractionBox(points=None, show=False, show_handle=False, show_vertices=False, selection_box_drag=None, selection_box_final=None, transform_start=<napari.utils.transforms.transforms.Affine object at 0x000001D214FC7AF0>, transform_drag=<napari.utils.transforms.transforms.Affine object at 0x000001D214FC7B50>, transform_final=<napari.utils.transforms.transforms.Affine object at 0x000001D214FC7BB0>, transform=<napari.utils.transforms.transforms.Affine object at 0x000001D214FC7C10>, allow_new_selection=True, selected_vertex=None)), help='', status='Ready', tooltip=Tooltip(visible=False, text=''), theme='dark', title='napari', mouse_move_callbacks=[<function InteractionBoxMouseBindings.initialize_mouse_events.<locals>.mouse_move at 0x000001D21BFEEB80>], mouse_drag_callbacks=[<function InteractionBoxMouseBindings.initialize_mouse_events.<locals>.mouse_drag at 0x000001D21BFEE700>], mouse_double_click_callbacks=[], mouse_wheel_callbacks=[<function dims_scroll at 0x000001D20511FC10>], _persisted_mouse_event={}, _mouse_drag_gen={}, _mouse_wheel_gen={}, keymap={'Shift': <function InteractionBoxMouseBindings.initialize_key_events.<locals>.hold_to_lock_aspect_ratio at 0x000001D21BFEE430>, 'Control-Shift-R': <function InteractionBoxMouseBindings._reset_active_layer_affine at 0x000001D21BFEE670>, 'Control-Shift-A': <function InteractionBoxMouseBindings._transform_active_layer at 0x000001D21BFEE5E0>})

# %%
icds,ncds = np.unique(dec.icodesN[dec.scoreA>dec.th],return_counts=True)
print(list(np.array(dec.gns_names)[icds[np.argsort(ncds)[::-1]]]))
# Out:
# ['NEFM', 'ACTG1', 'AKAP6', 'HS6ST3', 'KCNC2', 'CBLN2', 'IPO5', 'CDH13', 'GRM5', 'ELAVL4', 'DST', 'NCAM2', 'ITPR1', 'CA10', 'CBX5', 'CNTNAP4', 'KPNA1', 'KCNIP2', 'HTT', 'CHMP2A', 'KPNB1', 'CNR1', 'MLIP', 'NDEL1', 'NEFH', 'CHMP1A', 'GLIS3', 'AQP4', 'HIF3A', 'ISG20', 'HOXA7', 'CXCL14', 'MRC1', 'KLHL1', 'NEAT1', 'GRIA1', 'EPHA6', 'FILIP1L', 'ELAVL2', 'CHMP3', 'B2M', 'C1QL3', 'NRG1', 'HHIPL1', 'DSG3', 'BCHE', 'KPNA3', 'NUP133', 'MYO18A', 'ADARB2', 'CSE1L', 'LRIG3', 'CDK20', 'GRID2', 'KIRREL3', 'HPSE2', 'GSX1', 'HOXD8', 'CSF1R', 'IPO9', 'COLEC12', 'CLEC5A', 'CAPN2', 'COL20A1', 'LPIN1', 'LINC01107', 'AH
0091', 'blank0117', 'blank0075', 'blank0137', 'blank0174', 'blank0180', 'blank0184', 'blank0060', 'blank0187', 'blank0028', 'blank0086', 'blank0014', 'blank0107', 'blank0027', 'blank0156', 'blank0007', 'blank0054', 'blank0182', 'blank0162', 'blank0149', 'blank0042', 'blank0081', 'blank0126', 'blank0051', 'blank0146', 'blank0059', 'blank0105', 'blank0087', 'blank0061', 'blank0100', 'blank0140', 'blank0114', 'blank0092', 'blank0159', 'blank0030', 'blank0080', 'blank0101', 'blank0035', 'blank0015', 'blank0106', 'blank0039', 'blank0009', 'blank0160', 'blank0076', 'blank0120', 'blank0110', 'blank0052', 'blank0103', 'blank0048', 'blank0085', 'blank0065', 'blank0006', 'blank0109', 'blank0161', 'blank0154', 'blank0123', 'blank0099', 'blank0129', 'blank0062', 'blank0000', 'blank0036', 'blank0074', 'APLP2', 'blank0046', 'blank0124', 'blank0053', 'blank0142', 'blank0034', 'blank0055', 'blank0143', 'blank0078', 'blank0181', 'blank0175', 'blank0008', 'blank0058', 'blank0044', 'blank0185', 'blank0155', 'blank0001', 'blank0005', 'blank0019', 'blank0116', 'blank0047', 'blank0098', 'blank0158', 'blank0097', 'blank0179', 'blank0003', 'blank0165', 'blank0024', 'blank0002', 'blank0066', 'blank0069', 'blank0073', 'blank0157', 'blank0177', 'blank0093', 'blank0164', ' ...

# %%
viewer = plot_multigenes(dec,genes=['LMNA','LMNB1'],colors=['r','g','b','m','c','y','w'],viewer = None,
                         smin=2,smax=20)

# %%
viewer = plot_multigenes(dec,genes=['AQP4','KCNC2','NEFM','NUP133','NCAM2','HTT'],colors=['r','g','b','m','c','y','w'],viewer = None,
                         smin=2,smax=20)

# %%
# Out:
# ['NEFM', 'ACTG1', 'AKAP6', 'HS6ST3', 'KCNC2', 'CBLN2', 'IPO5', 'CDH13', 'GRM5', 'ELAVL4', 'DST', 'NCAM2', 'ITPR1', 'CA10', 'CBX5', 'CNTNAP4', 'KPNA1', 'KCNIP2', 'HTT', 'CHMP2A', 'KPNB1', 'CNR1', 'MLIP', 'NDEL1', 'NEFH', 'CHMP1A', 'GLIS3', 'AQP4', 'HIF3A', 'ISG20', 'HOXA7', 'CXCL14', 'MRC1', 'KLHL1', 'NEAT1', 'GRIA1', 'EPHA6', 'FILIP1L', 'ELAVL2', 'CHMP3', 'B2M', 'C1QL3', 'NRG1', 'HHIPL1', 'DSG3', 'BCHE', 'KPNA3', 'NUP133', 'MYO18A', 'ADARB2', 'CSE1L', 'LRIG3', 'CDK20', 'GRID2', 'KIRREL3', 'HPSE2', 'GSX1', 'HOXD8', 'CSF1R', 'IPO9', 'COLEC12', 'CLEC5A', 'CAPN2', 'COL20A1', 'LPIN1', 'LINC01107', 'AHCTF1', 'BRAP', 'FTH1', 'GLRA3', 'CHMP6', 'LEMD2', 'FZD7', 'CYP4B1', 'FGF10', 'CBLN1', 'CD74', 'LMNTD1', 'DOCK8', '
156', 'blank0007', 'blank0054', 'blank0182', 'blank0162', 'blank0149', 'blank0042', 'blank0081', 'blank0126', 'blank0051', 'blank0146', 'blank0059', 'blank0105', 'blank0087', 'blank0061', 'blank0100', 'blank0140', 'blank0114', 'blank0092', 'blank0159', 'blank0030', 'blank0080', 'blank0101', 'blank0035', 'blank0015', 'blank0106', 'blank0039', 'blank0009', 'blank0160', 'blank0076', 'blank0120', 'blank0110', 'blank0052', 'blank0103', 'blank0048', 'blank0085', 'blank0065', 'blank0006', 'blank0109', 'blank0161', 'blank0154', 'blank0123', 'blank0099', 'blank0129', 'blank0062', 'blank0000', 'blank0036', 'blank0074', 'APLP2', 'blank0046', 'blank0124', 'blank0053', 'blank0142', 'blank0034', 'blank0055', 'blank0143', 'blank0078', 'blank0181', 'blank0175', 'blank0008', 'blank0058', 'blank0044', 'blank0185', 'blank0155', 'blank0001', 'blank0005', 'blank0019', 'blank0116', 'blank0047', 'blank0098', 'blank0158', 'blank0097', 'blank0179', 'blank0003', 'blank0165', 'blank0024', 'blank0002', 'blank0066', 'blank0069', 'blank0073', 'blank0157', 'blank0177', 'blank0093', 'blank0164', ' ...

# %%
??plot_statistics
# Out:
# Signature: plot_statistics(dec)
# Docstring: <no docstring>
# Source:
# def plot_statistics(dec):
#     if hasattr(dec,'im_segm_'):
#         ncells = len(np.unique(dec.im_segm_))-1
#     else:
#         ncells = 1
#     icds,ncds = np.unique(dec.icodesN[dec.scoreA>dec.th],return_counts=True)
#     good_igns = [ign for ign,gn in enumerate(dec.gns_names) if 'blank' not in gn.lower()]
#     kp = np.in1d(icds,good_igns)
#     ncds = ncds/ncells
#     plt.figure()
#     plt.xlabel('Genes')
#     plt.plot(icds[kp],ncds[kp],label='genes')
#     plt.plot(icds[~kp],ncds[~kp],label='blank')
#     plt.ylabel('Number of molecules in the fov')
#     plt.title(str(np.round(np.mean(ncds[~kp])/np.mean(ncds[kp]),3)))
#     plt.legend()
# File:      c:\scripts\nmerfish\iomicro.py
# Type:      function

# %%
#np.unique(dec.XH_pruned[:,:,-1])

# %%
if True:
    dec.XH_save = dec.XH.copy()
    keep_best_N_for_each_Readout(dec,Nkeep = 15000)
    dec.get_inters(dinstance_th=5,enforce_color=True)# enforce_color=False
    dec.get_icodes(nmin_bits=4,method = 'top4',norm_brightness=-1)
    apply_fine_drift(dec,plt_val=True)
    dec.XH = dec.XH_save.copy()
    R = dec.XH[:,-1].astype(int)
    dec.XH[:,:3] -= dec.drift_arr[R]

dec.get_inters(dinstance_th=2,enforce_color=True)# enforce_color=False
dec.get_icodes(nmin_bits=4,method = 'top4',norm_brightness=None,nbits=24,is_unique=False)

# %% [markdown]
# ### Pick a few calibration FOVs

# %%
save_folder =r'\\192.168.0.21\bbfishdc21\HttHuman_Snonia__06_12_2023\MERFISH_Analysis_group1'
fov,set_ = 'Conv_zscan__30', '_set5'
dec = decoder_simple(save_folder,fov,set_)
dec.ncols=2
dec.load_decoded()
apply_fine_drift(dec,plt_val=True)
scoresRefT = get_score_per_color(dec)
# Out:
# Loaded decoded: -0.01915764808654785
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 74.24it/s]

# %%
if False:
    if scoresRef is None: scoresRef=scoresRefT
    else: combine_scoresRef(scoresRef,scoresRefT)
    np.save(save_folder+os.sep+'scoresRef.npy',scoresRef)

# %% [markdown]
# ### Given the base decoding for each fov, run across all datasets with consistent values

# %%
from ioMicro import *
save_folder =r'\\192.168.0.6\bbfish1e3\DCBBL1_03_14_2023_big\MERFISH_Analysis'
scoresRef = np.load(save_folder+os.sep+'scoresRef.npy',allow_pickle=True)

# %%
#elems = [('Conv_zscan__'+str(ifov).zfill(3),'_'+set_)for set_ in ['set2'] for ifov in dic_f[set_]]
for fov,set_ in tqdm(elems):
    save_final_decoding(save_folder,fov,set_,scoresRef,th=-1.5,plt_val=False,
                            tags_smFISH=['Aldh','Sox11'],
                            genes_smFISH=[['Igfbpl1','Aldh1l1','Ptbp1'],['Sox11','Sox2','Dcx']],Hths=None,force=True)

# %% [markdown]
# ### Get counts per cell into a single dataset

# %%
import pandas as pd
save_folder =r'\\192.168.0.6\bbfish1e3\DCBBL1_03_14_2023_big\MERFISH_Analysis'
#save_folder =r'\\192.168.0.6\bbfish1e3\DCBBL1_03_14_2023_big\MERFISH_Analysis'
save_fls = glob.glob(save_folder+os.sep+'finaldecs_*')

# %%
save_fls_ = [fl for fl in save_fls if ('_set5' in fl)]# in fl if '035' in fl][0]
cell_df,df=None,None
for save_fl in tqdm(np.sort(save_fls_)[:]):
    ### load info
    dic = np.load(save_fl)
    XF = dic['XF']
    header = list(dic['header'])
    genes_decoded = dic['genes']
    cells = dic['cellinfo'][1:]
    header_cells = dic['header_cells']
    ### Rethrehold based on score
    iscore = list(header).index('score')
    scoreA = XF[:,iscore]
    keep = scoreA>-1.5
    ugns,gns_i = np.unique(genes_decoded[keep],return_inverse=True)

    icell = header.index('cell_id')
    icells = XF[keep,icell].astype(int)
    
    icellsf = cells[:,0].astype(int)
    
    mcell = np.max(icellsf)+1
    gn_cell,gn_cell_cts = np.unique(mcell*gns_i+icells,return_counts=True)
    len(gn_cell)
    igns_ = gn_cell//mcell
    icells_ = gn_cell%mcell
    Mcts = np.zeros([mcell,len(ugns)])
    Mcts[icells_,igns_]=gn_cell_cts

    Mcts[icellsf].shape
    ifov,iset = int(XF[0,header.index('ifov')]),int(XF[0,header.index('iset')])
    icellsnm = [icell+10**5*ifov for icell in icellsf]#icellsnm = [icell+10**5*ifov+10**9*iset for icell in icellsf]

    dfT = pd.DataFrame(Mcts[icellsf],columns=ugns,index=icellsnm)


    df = dfT if df is None else pd.concat([df,dfT])
    cell_dfT = pd.DataFrame(cells,columns=header_cells,index=icellsnm)
    cell_df = cell_dfT if cell_df is None else pd.concat([cell_df,cell_dfT])

# %%
dfT = pd.DataFrame(Mcts[icellsf],columns=ugns,index=icellsnm)
