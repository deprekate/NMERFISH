# %%
from ioMicro import *

# %%
save_folder =r'\\192.168.0.6\bbfishjoy4\CGBB_embryo_4_28_2023\MERFISH_Analysis3'

fls = glob.glob(save_folder+os.sep+'decoded*')

# %%
len(fls)
# Out:
# 796

# %%
fov_fls = glob.glob(save_folder+os.sep+'*fov*')

# %%
fls_all = [fl_ for fl in fov_fls for fl_ in np.load(fl)]
len(fls_all)
# Out:
# 797

# %%
\\192.168.0.6\bbfishjoy4extra

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 0A7F-5FFC
#
#  Directory of C:\Users\BintuLabUser\BintuLabScripts1\MERFISH_DC_SCOPE2\Analysis_1500gns_MERFISH_dev
#
# 06/18/2023  09:55 PM    <DIR>          .
# 06/18/2023  09:55 PM    <DIR>          ..
# 06/01/2023  02:54 PM    <DIR>          .ipynb_checkpoints
# 06/09/2023  11:24 PM           504,345 BlankBarcodes.ipynb
# 06/18/2023  09:55 PM            68,943 CheckProgress.ipynb
# 05/16/2023  07:18 PM            45,074 codebook_Mahsa_DevP1P2-code_color2__comb16-4-4.csv
# 05/18/2023  03:43 PM            93,808 codebook_Mahsa_DevP1P2-code_color2__comb16-4-4_blank.csv
# 05/16/2023  07:19 PM                 0 codebook_Mahsa_DevP3P4-code_color2__comb16-4-4.csv
# 06/01/2023  05:49 AM            39,702 fftconvolve_torch.ipynb
# 05/26/2023  02:54 PM             2,503 FlatFieldCorrection.ipynb
# 06/01/2023  03:47 PM           130,904 ioMicro.py
# 06/01/2023  06:09 AM           130,785 ioMicro.py.bak
# 05/18/2023  06:19 PM           108,642 ioMicroOld.py
# 05/31/2023  08:11 AM           461,532 psf_750_Scope1_embryo.npy
# 05/31/2023  02:31 PM         1,815,612 psf_750_Scope1_embryo_big.npy
# 06/01/2023  04:43 AM           968,128 psf_750_Scope1_embryo_big_final.npy
# 05/31/2023  12:26 PM           461,532 psf_750_Scope1_embryo_small.npy
# 06/01/2023  03:52 PM            57,381 Untitled.ipynb
# 06/02/2023  10:18 AM             7,003 worker_Scope1.py
# 06/01/2023  03:50 PM             7,003 worker_Scope1.py.bak
# 06/13/2023  08:15 AM             7,156 worker_Scope1__EmbryoPlate56.py
# 06/13/2023  08:12 AM             7,013 worker_Scope1__EmbryoPlate56.py.bak
# 06/01/2023  03:48 PM    <DIR>          __pycache__
#               19 File(s)      4,917,066 bytes
#                4 Dir(s)  3,069,352,710,144 bytes free

# %%
len(fls)
# Out:
# 471

# %%
times = [os.path.getctime(fl) for fl in fls]

# %%
diffT = np.diff(np.sort(times)).astype(int)
np.median(diffT)/60./60./24.*700
# Out:
# 6.623263888888888

# %%
data_fld=r'\\192.168.0.6\bbfishjoy4\CGBB_embryo_4_28_2023\H2_MER*'
fovs = glob.glob(data_fld+os.sep+'*.zarr')

# %%
np.unique([os.path.basename(os.path.dirname(fl))for fl in fovs],return_counts=True)
# Out:
# (array(['H2_MER_D13', 'H2_MER_D14', 'H2_MER_D16', 'H2_MER_D7', 'H2_MER_D9'],
#        dtype='<U10'),
#  array([191, 256, 259,  31,  60], dtype=int64))

# %%
from ioMicro import *

save_folder =r'\\192.168.0.6\bbfishjoy4extra\MERFISH_AnalysisP56'
fov,set_ = 'Conv_zscan__059','_D16'
dec = decoder_simple(save_folder,fov,set_)
dec.load_decoded()
# Out:
# Loaded decoded: -5.294854164123535

# %%
apply_fine_drift(dec,plt_val=True)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████| 48/48 [00:10<00:00,  4.54it/s]

# %%
dec.ncols=3
scoresRef = get_score_per_color(dec)

# %%
get_score_withRef(dec,scoresRef,plt_val=True,gene=None,iSs = None)

# %%
dec.th=-1.
plot_statistics(dec)

# %%
dec.th=-1.5
plot_statistics(dec)

# %%
viewer = plot_multigenes(dec,genes=['Dlx6os1','Apoe','Elavl3','Bsg','Col3a1','Eln'],colors=['r','g','b','m','c','y','w'],viewer = None,
                         smin=5,smax=20)

# %%
viewer = plot_multigenes(dec,genes=['Olig1','Sox9','Smad3'],colors=['r','g','b','m','c','y','w'],viewer = None,
                         smin=5,smax=20)

# %%
#dec.gns_names
# Out:
# array(['Necab3', 'Nefh', 'Nefm', 'Neurog1', 'Neurog2', 'Nfib', 'Ngb',
#        'Ngef', 'Nhlh2', 'Nkx2-1', 'Nmb', 'Nmbr', 'Notch3', 'Nov', 'Npm1',
#        'Npnt', 'Nptx1', 'Npy2r', 'Nr3c2', 'Nrg3', 'Nrp1', 'Nupr1',
#        'Nusap1', 'Ocln', 'Odf3b', 'Ogt', 'Olfml3', 'Olig2', 'Omd',
#        'Opcml', 'Pantr1', 'Pax6', 'Pax7', 'Pbx1', 'Pbxip1', 'Pcbp3',
#        'Pclaf', 'Pcna', 'Pcp4', 'Pde7b', 'Pdzrn4', 'Pecam1', 'Peg10',
#        'Pgr', 'Pifo', 'Pipox', 'Pkd2l1', 'Pkib', 'Plb1', 'Plin2', 'Pllp',
#        'Plp1', 'Pltp', 'Pmch', 'Pold3', 'Pou3f1', 'Pou3f2', 'Pou4f1',
#        'Ppfia2', 'Ppm1l', 'Ppp1r14b', 'Ppp1r1a', 'Prss12', 'Prss56',
#        'Psap', 'Psrc1', 'Pthlh', 'Ptn', 'Ptprj', 'Rangap1', 'Rasd1',
#        'Rasgrf2', 'Rasgrp1', 'Rasl10a', 'Rasl11a', 'Rbfox3', 'Rbp1',
#        'Reg3g', 'Rfx3', 'Rgcc', 'Rgma', 'Rgs10', 'Rgs12', 'Rhcg', 'Rhov',
#        'Riiad1', 'Rims4', 'Rorb', 'Rpa2', 'Rpl26', 'Rpl29', 'Rpl35',
#        'Rpl38', 'Rpl5', 'Rspo3', 'Rtn4', 'Rwdd3', 'S100a10', 'Sag',
#        'Satb2', 'Scg2', 'Scrg1', 'Scube1', 'Selenop', 'Selplg', 'Sema3a',
#        'Sema3c', 'Sema3d', 'Sema3e', 'Sema3g', 'Sirt2', 'Ska1', 'Slbp',
#        'Slc12a7', 'Slc16a1', 'Slc17a7', 'Slc1a3', 'Slc6a13', 'Slc6a2',
#        'Slc6a20a', 'Slc6a4', 'Slco1c1', 'Slit2', 'Slit3', 'Slitrk6',
#        'Sln', 'Smad3', 'Smc2', 'Smim3', 'Snap25', 'Sncg', 'Snhg18',
#        'Sorcs1', 'Sox10', 'Sox11', 'Spp1', 'Sprr2a2', 'Spsb4', 'Ssbp2',
#        'Sspo', 'Sst', 'Sstr2', 'Stum', 'Sub1', 'Sulf1', 'Sulf2', 'Sv2c',
#        'Necab2', 'Nectin3', 'Nefl', 'Nell1', 'Nes', 'Neto1', 'Neu4',
#        'Neurod1', 'Neurod2', 'Neurod4', 'Neurod6', 'Nos2', 'Notch1',
#        'Npas1', 'Npas3', 'Npb', 'Npff', 'Nptxr', 'Npy', 'Nrep', 'Nrn1',
#        'Nrxn3', 'Ntf3', 'Ntn1', 'Ntng1', 'Ntrk2', 'Nts', 'Ntsr2', 'Nuf2',
#        'Opalin', 'Pam', 'Parvg', 'Pax3', 'Pax5', 'Pcdh11x', 'Pcdh17',
#        'Pcdh19', 'Pcdh20', 'Pcp2', 'Pcp4l1', 'Pde10a', 'Pde1a', 'Pde6g',
#        'Penk', 'Pex5l', 'Pfkm', 'Pglyrp1', 'Pla2g2e', 'Plch1', 'Pld4',
#        'Plekha1', 'Plekha2', 'Plekhg1', 'Pnoc', 'Pnrc1', 'Pola1',
#        'Ppp2r2b', 'Pramel4', 'Prc1', 'Prex2', 'Prickle2', 'Prim1',
#        'Prima1', 'Prkcg', 'Prkg1', 'Prlr', 'Ptma', 'Ptprd', 'Qpct',
#        'Qrfpr', 'Rab3b', 'Rab3c', 'Rac3', 'Rad51', 'Rad51ap1', 'Ramp3',
#        'Reep5', 'Rfc2', 'Rgs14', 'Rgs16', 'Rgs2', 'Rgs4', 'Rgs5', 'Rhoh',
#        'Rln1', 'Rln3', 'Rnase1', 'Rnasel', 'Rnd2', 'Rnf121', 'Rnf152',
#        'Rps20', 'Rrm1', 'Rrm2', 'Rspo1', 'Rtn1', 'Runx1t1', 'S100a1',
#        'S1pr3', 'Satb1', 'Scd2', 'Scn9a', 'Sdk1', 'Selenbp1', 'Serpinf1',
#        'Serping1', 'Sfrp1', 'Sgcd', 'Sgcz', 'Sgk1', 'Shisa8', 'Shox2',
#        'Siglece', 'Slc13a4', 'Slc17a6', 'Slc1a2', 'Slc1a6', 'Slc22a3',
#        'Slc22a8', 'Slc25a18', 'Slc25a4', 'Slc2a1', 'Slc30a3', 'Slc32a1',
#        'Slc38a5', 'Slc39a4', 'Slc44a3', 'Slc47a1', 'Slc4a4', 'Slc5a7',
#        'Slc6a1', 'Slc6a11', 'Sost', 'Sox2', 'Sox4', 'Sox5', 'Sox6',
#        'Sox9', 'Sp9', 'Spag5', 'Sparc', 'Sphkap', 'Spink8', 'Spock1',
#        'Negr1', 'Nek2', 'Nfia', 'Nfix', 'Nin', 'Nkain2', 'Nkain4', 'Nme5',
#        'Nmu', 'Nmur2', 'Nnat', 'Nog', 'Nos1', 'Nppa', 'Npsr1', 'Nr2f2',
#        'Nr4a2', 'Nrgn', 'Nrp2', 'Nrsn1', 'Nxph1', 'Nxph3', 'Nxph4',
#        'Oasl2', 'Olig1', 'Olr1', 'Omg', 'Orm2', 'Orm3', 'Osr1', 'Otp',
#        'Otx2', 'Oxt', 'P2ry12', 'P2ry13', 'Pabpc2', 'Padi2', 'Pdgfra',
#        'Pdgfrb', 'Pdhb', 'Pdk4', 'Pdlim1', 'Pdlim4', 'Pdlim5', 'Pdyn',
#        'Pkm', 'Plcb4', 'Plp2', 'Plpp3', 'Plppr4', 'Plxna1', 'Pnmt',
#        'Pomc', 'Ppp1r1b', 'Ppp1r3g', 'Ppp3ca', 'Prok2', 'Prom1', 'Prox1',
#        'Prph', 'Ptbp2', 'Ptger1', 'Ptgs1', 'Ptk2b', 'Ptprc', 'Ptpro',
#        'Ptprz1', 'Ptx3', 'Pvalb', 'Qk', 'Rbm24', 'Rbm3', 'Rbms3', 'Rell1',
#        'Reln', 'Rem2', 'Resp18', 'Rest', 'Ret', 'Rexo2', 'Rlbp1',
#        'Rnf182', 'Robo1', 'Rora', 'Rpl7a', 'Rpp25', 'Rprm', 'Rps19',
#        'Rpsa', 'Rras2', 'Rsph4a', 'Rtbdn', 'Rtp4', 'Rxfp1', 'S100b',
#        'Sall1', 'Sall3', 'Sap30bpos', 'Sapcd1', 'Sdk2', 'Sema6d', 'Sept4',
#        'Serinc5', 'Serpine2', 'Sin3a', 'Six3', 'Sla2', 'Slc10a4',
#        'Slc12a2', 'Slc12a5', 'Slc17a8', 'Slc18a2', 'Slc18a3', 'Slc1a1',
#        'Slc6a3', 'Slc6a5', 'Slc6a9', 'Slc7a10', 'Slc7a5', 'Slc9a1',
#        'Slpi', 'Smarca4', 'Smc4', 'Snca', 'Snhg11', 'Snrpg', 'Sorcs3',
#        'Sox14', 'Sox17', 'Spp2', 'Sprr2b', 'Srsf2', 'St3gal3',
#        'St6galnac5', 'St8sia6', 'Stac2', 'Stard8', 'Stc1', 'Steap4',
#        'Stmn1', 'Stox2', 'blank0000', 'blank0001', 'blank0002',
#        'blank0003', 'blank0004', 'blank0005', 'blank0006', 'blank0007',
#        'blank0008', 'blank0009', 'blank0010', 'blank0011', 'blank0012',
#        'blank0013', 'blank0014', 'blank0015', 'blank0016', 'blank0017',
#        'blank0018', 'blank0019', 'blank0020', 'blank0021', 'blank0022',
#        'blank0023', 'blank0024', 'blank0025', 'blank0026', 'blank0027',
#        'blank0028', 'blank0029', 'blank0030', 'blank0031', 'blank0032',
#        'blank0033', 'blank0034', 'blank0035', 'blank0036', 'blank0037',
