# %%
from ioMicro import *

# %%
from Human.workerScope3A_HttHuman_Snonia__06_12_2023_P2G1_V2 import *

# %%
#compute_drift(save_folder,fov,all_flds,set_,redo=False,gpu=False)

# %%
set_ = '_set5'
save_folder,all_flds,fov = get_files((set_,30))
compute_drift(save_folder,fov,all_flds,set_,redo=False,gpu=False)

# %%
fov,set_ = 'Conv_zscan__30','_set5'
dec = decoder_simple(save_folder,fov=fov,set_=set_)
dec.get_XH(fov,set_,ncols=2,nbits=12,th_h=6000)#number of colors match 
dec.XH = dec.XH[dec.XH[:,-4]>0.25] ### keep the spots that are correlated with the expected PSF for 60X
dec.load_library(lib_fl,nblanks=-1)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 12/12 [00:04<00:00,  2.82it/s]

# %%
#[drft[:3]for drft in dec.drifts]

# %%
import torch

# %%
get_inters(dec,dinstance_th=2,nmin_bits=4,enforce_color=True,redo=True)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:22<00:00, 11.08s/it]
# Calculating lengths of clusters...
# Unfolding indexes...
# Saving to file: \\192.168.0.21\bbfishdc21\HttHuman_Snonia__06_12_2023\MERFISH_Analysis_group3\res_Conv_zscan__30--_set5.npz

# %%
def get_icodes(dec,nmin_bits=4,delta_bits=None,iH=-3,redo=False,norm_brightness=False,nbits=24,is_unique=False):
    import time
    start = time.time()
    lens = dec.lens
    res_unfolder = dec.res_unfolder
    Mlen = np.max(lens)
    print("Calculating indexes within cluster...")
    res_is = np.tile(np.arange(Mlen), len(lens))
    res_is = res_is[res_is < np.repeat(lens, Mlen)]
    print("Calculating index of molecule...")
    ires = np.repeat(np.arange(len(lens)), lens)
    #r0 = np.array([r[0] for r in res for r_ in r])
    print("Calculating index of first molecule...")
    r0i = np.concatenate([[0],np.cumsum(lens)])[:-1]
    r0 = res_unfolder[np.repeat(r0i, lens)]
    print("Total time unfolded molecules:",time.time()-start)

    ### torch
    ires = torch.from_numpy(ires.astype(np.int64))
    res_unfolder = torch.from_numpy(res_unfolder.astype(np.int64))
    res_is = torch.from_numpy(res_is.astype(np.int64))
    
    
    
    ### get score for brightness 
    def get_scoresH():
        H = torch.from_numpy(dec.XH[:,-3])
        Hlog = H#np.log(H)
        mnH = Hlog.mean()
        stdH = Hlog.std()
        distribution = torch.distributions.Normal(mnH, stdH)
        scoreH = distribution.cdf(Hlog)
        return scoreH[res_unfolder]
    ### get score for inter-distance between molecules
    def get_scoresD():
        X = dec.XH[:,:3]
        XT = torch.from_numpy(X)
        XD = XT[res_unfolder]-XT[r0]
        meanD = -torch.mean(torch.abs(XD),axis=-1)
        distribution = torch.distributions.Normal(meanD.mean(), meanD.std())
        scoreD = distribution.cdf(meanD)
        return scoreD
    def get_combined_scores():
        scoreH = get_scoresH()
        scoreD = get_scoresD()
        ### combine scores. Note this score is for all the molecules un-ravelled from their clusters
        scoreF = scoreD*scoreH
        return scoreF
    
    import time
    start = time.time()
    print("Computing score...")
    if iH is None:
        scoreF = get_combined_scores()
    else:
        scoreF = torch.from_numpy(dec.XH[:,iH])[res_unfolder]
    print("Total time computing score:",time.time()-start)

    ### organize molecules in blocks for each cluster
    def get_asort_scores():
        val = torch.max(scoreF)+2
        scoreClu = torch.zeros([len(lens),Mlen],dtype=torch.float64)+val
        scoreClu[ires,res_is]=scoreF
        asort = scoreClu.argsort(-1)
        scoreClu = torch.gather(scoreClu,dim=-1,index=asort)
        scoresF2 = scoreClu[scoreClu<val-1]
        return asort,scoresF2
    def get_reorder(x,val=-1):
        if type(x) is not torch.Tensor:
            x = torch.from_numpy(np.array(x))
        xClu = torch.zeros([len(lens),Mlen],dtype=x.dtype)+val
        xClu[ires,res_is] = x
        xClu = torch.gather(xClu,dim=-1,index=asort)
        xf = xClu[xClu>val]
        return xf

    import time
    start = time.time()
    print("Computing sorting...")
    asort,scoresF2 = get_asort_scores()
    res_unfolder2 = get_reorder(res_unfolder,val=-1)
    del asort
    del scoreF
    print("Total time sorting molecules by score:",time.time()-start)
    
    
    
    import time
    start = time.time()
    print("Finding best bits per molecules...")

    Rs = dec.XH[:,-1].astype(np.int64)
    Rs = torch.from_numpy(Rs)
    Rs_U = Rs[res_unfolder2]

    score_bits = torch.zeros([len(lens),nbits],dtype=scoresF2.dtype)-1
    score_bits[ires,Rs_U]=scoresF2

    
    codes_lib = torch.from_numpy(np.array(dec.codes__))
    codes_lib_01 = torch.zeros([len(codes_lib),nbits],dtype=score_bits.dtype)
    for icd,cd in enumerate(codes_lib):
        codes_lib_01[icd,cd]=1

    print("Finding best code...")
    batch = 10000
    icodes_best = torch.zeros(len(score_bits),dtype=torch.int64)
    for i in tqdm(range((len(score_bits)//batch)+1)):
        score_bits_ = score_bits[i*batch:(i+1)*batch]
        if len(score_bits_)>0:
            icodes_best[i*batch:(i+1)*batch] = torch.argmax(torch.matmul(score_bits_,codes_lib_01.T),dim=-1)
    
    
    #argsort_bits = torch.argsort(score_bits,dim=-1,descending=True)[:,:(nmin_bits+delta_bits)]
    dec.score_bits = score_bits
    dec.codes_lib = codes_lib
    dec.icodes_best = icodes_best
    
    if delta_bits is not None:
        argsort_bits = torch.argsort(score_bits,dim=-1,descending=True)[:,:(nmin_bits+delta_bits)]
        score_bits_ = score_bits*0
        score_bits_.scatter_(1, argsort_bits, 1)
        keep_all_bits = torch.all(score_bits_.gather(1,codes_lib[icodes_best])>0.5,-1)
    else:
        keep_all_bits = torch.all(score_bits.gather(1,codes_lib[icodes_best])>=0,-1)
        
    score_bits = score_bits[keep_all_bits]
    icodes_best_ = icodes_best[keep_all_bits]
    
    
    
    indexMols_ = torch.zeros([len(lens),nbits],dtype=res_unfolder2.dtype)-1
    indexMols_[ires,Rs_U]=res_unfolder2
    indexMols_ = indexMols_[keep_all_bits]
    indexMols_ = indexMols_.gather(1,codes_lib[icodes_best_])
    XH = torch.from_numpy(dec.XH)
    XH_pruned = XH[indexMols_]
    icodesN=icodes_best_
    dec.XH_pruned=XH_pruned.numpy()
    dec.icodesN=icodesN.numpy()

    print("Total time best bits per molecule:",time.time()-start)

# %%
get_icodes(dec,nmin_bits=4,delta_bits=None,iH=-3,redo=False,norm_brightness=False,nbits=24,is_unique=False)
# Out:
# Calculating indexes within cluster...
# Calculating index of molecule...
# Calculating index of first molecule...
# Total time unfolded molecules: 2.290412664413452
# Computing score...
# Total time computing score: 0.1451127529144287
# Computing sorting...
# Total time sorting molecules by score: 3.6296162605285645
# Finding best bits per molecules...
# Finding best code...
# 100%|███████████████████████████████████████████████████████████████████████████████| 966/966 [00:06<00:00, 152.26it/s]
# Total time best bits per molecule: 8.582155704498291

# %%
X_ = dec.XH_pruned[:,:,:3]
d = np.linalg.norm(X_-X_.mean(1)[:,np.newaxis],axis=-1)
h = np.log(dec.XH_pruned[:,:,-3])
ibad = [ign for ign,gn in enumerate(dec.gns_names) if 'blank' in gn]
bad = np.in1d(dec.icodesN,ibad)
good = ~bad
plt.hist(h[good].ravel(),density=True,alpha=0.75,bins=500);
plt.hist(h[bad].ravel(),density=True,alpha=0.75,bins=500);
plt.figure()
plt.title("Distance")
plt.hist(d[good].ravel(),density=True,alpha=0.75,bins=500);
plt.hist(d[bad].ravel(),density=True,alpha=0.75,bins=500);

# %%
dec.decoded_fl
# Out:
# '\\\\192.168.0.21\\bbfishdc21\\HttHuman_Snonia__06_12_2023\\MERFISH_Analysis_group3\\decoded_Conv_zscan__30--_set5.npz'

# %%
get_inters(dec,dinstance_th=1.75,nmin_bits=4,enforce_color=True,redo=True)
get_icodesV2(dec,nmin_bits=4,delta_bits=None,iH=-3,redo=False,norm_brightness=False,nbits=24,is_unique=True)
icds,ncts = np.unique(dec.icodesN,return_counts=True)
ibad = [ign for ign,gn in enumerate(dec.gns_names) if 'blank' in gn]
bad = np.in1d(icds,ibad)
good = ~bad
plt.plot(icds[good],ncts[good])
plt.plot(icds[bad],ncts[bad])
np.median(ncts[good])/np.median(ncts[bad])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:20<00:00, 10.48s/it]
# Calculating lengths of clusters...
# Unfolding indexes...
# Saving to file: \\192.168.0.21\bbfishdc21\HttHuman_Snonia__06_12_2023\MERFISH_Analysis_group3\res_Conv_zscan__30--_set5.npz
# Calculating indexes within cluster...
# Calculating index of molecule...
# Calculating index of first molecule...
# Total time unfolded molecules: 0.4607272148132324
# Computing score...
# Total time computing score: 0.0319974422454834
# Computing sorting...
# Total time sorting molecules by score: 0.7729103565216064
# Finding best bits per molecules...
# Finding best code...
# 100%|███████████████████████████████████████████████████████████████████████████████| 218/218 [00:01<00:00, 152.80it/s]
# Total time best bits per molecule: 19.039849042892456
# 4.431746031746032

# %%
X_ = dec.XH_pruned[:,:,:3]
d = np.linalg.norm(X_-X_.mean(1)[:,np.newaxis],axis=-1)
h = np.log(dec.XH_pruned[:,:,-3])
ibad = [ign for ign,gn in enumerate(dec.gns_names) if 'blank' in gn]
bad = np.in1d(dec.icodesN,ibad)
good = ~bad
stds = np.array([-np.std(d),np.std(h)])
start=np.array([np.percentile(d,99),np.percentile(h,1)])
t = 0.
new_th = stds*t+start
keep_all = np.all(d<new_th[0],axis=-1)&np.all(h>new_th[1],axis=-1)
np.mean(keep_all[bad]),np.mean(keep_all[good]),np.sum(keep_all[good])/np.sum(keep_all[bad]),new_th
# Out:
# (0.8515381101043173,
#  0.9329182731252573,
#  9.42286455189681,
#  array([1.44745212, 9.13148881]))

# %%
np.array(dec.gns_names)[icds[np.argsort(ncts)[::-1]]][:50]
# Out:
# array(['APP', 'SLC17A7', 'TUBB4A', 'ANK2', 'VSNL1', 'RBFOX1', 'RANGAP1',
#        'SNCB', 'SPOCK1', 'ATP1B1', 'TUBA4A', 'SATB2', 'CACNA1A', 'OLFM3',
#        'SORT1', 'CD81', 'RASGRF2', 'PLEC', 'TUBB3', 'XPO7', 'PLP1', 'RAN',
#        'ADGRG1', 'CASP7', 'ZNF385D', 'SUN1', 'PAX6', 'TARDBP', 'TAFA2',
#        'SLC32A1', 'COX7A2L', 'UNC13C', 'RANBP3', 'NUP205', 'STARD13',
#        'TNPO3', 'SPTBN4', 'CACNA1D', 'TRPM3', 'PLCH1', 'CD63', 'BAD',
#        'TUBB', 'SLN', 'ATP6AP2', 'PLA2G4C', 'PDE4B', 'CACNA1H', 'TUBG1',
#        'blank0132'], dtype='<U10')

# %%
X_ = dec.XH_pruned[:,:,:3]
d = np.linalg.norm(X_-X_.mean(1)[:,np.newaxis],axis=-1)
h = np.log(dec.XH_pruned[:,:,-3])
dec.scoreA = np.exp(np.mean(h,axis=-1))
dec.th=0
viewer = plot_multigenes(dec,genes=['RAN','SLC17A7','PLP1'],colors=['r','g','b','m','c','y','w'],viewer = None,
                         smin=2,smax=30)

# %%
X_ = dec.XH_pruned[:,:,:3]
d = np.linalg.norm(X_-X_.mean(1)[:,np.newaxis],axis=-1)
h = np.log(dec.XH_pruned[:,:,-3])
ibad = [ign for ign,gn in enumerate(dec.gns_names) if 'blank' in gn]
bad = np.in1d(dec.icodesN,ibad)
good = ~bad
plt.hist(h[good].ravel(),density=True,alpha=0.75,bins=500);
plt.hist(h[bad].ravel(),density=True,alpha=0.75,bins=500);
plt.figure()
plt.title("Distance")
plt.hist(d[good].ravel(),density=True,alpha=0.75,bins=500);
plt.hist(d[bad].ravel(),density=True,alpha=0.75,bins=500);

# %%
stds = np.array([-np.std(d),np.std(h)])
start=np.array([np.percentile(d,99),np.percentile(h,1)])
t = 0
new_th = stds*t+start
keep_all = np.all(d<new_th[0],axis=-1)&np.all(h>new_th[1],axis=-1)
np.mean(keep_all[bad]),np.mean(keep_all[good]),np.sum(keep_all[good])/np.sum(keep_all[bad]),new_th
# Out:
# (0.9162022576656268,
#  0.926781139426319,
#  1.5421239101552204,
#  array([2.10708272, 9.12470067]))

# %%
np.log(9000)
# Out:
# 9.104979856318357

# %%
stds = np.array([-np.std(d),np.std(h)])
start=np.array([np.percentile(d,99),np.percentile(h,1)])
t = 1.0
new_th = stds*t+start
keep_all = np.all(d<new_th[0],axis=-1)&np.all(h>new_th[1],axis=-1)
np.mean(keep_all[bad]),np.mean(keep_all[good]),np.sum(keep_all[good])/np.sum(keep_all[bad])
# Out:
# (0.1416352322145071, 0.41082892076634253, 18.097031382527565)

# %%
new_th
# Out:
# array([1.46950214, 9.12729957])

# %%
#plt.plot(dec.XH[::1000,-5],dec.XH[::1000,-3],'o')

# %%
icds,ncts = np.unique(dec.icodesN,return_counts=True)

plt.plot(icds[good],ncts[good])
plt.plot(icds[bad],ncts[bad])
np.median(ncts[good])/np.median(ncts[bad])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[20], line 3
#       1 icds,ncts = np.unique(dec.icodesN,return_counts=True)
# ----> 3 plt.plot(icds[good],ncts[good])
#       4 plt.plot(icds[bad],ncts[bad])
#       5 np.median(ncts[good])/np.median(ncts[bad])
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is 374 but corresponding boolean dimension is 7386024

# %%
icds,ncts = np.unique(dec.icodesN,return_counts=True)
ibad = [ign for ign,gn in enumerate(dec.gns_names) if 'blank' in gn]
bad = np.in1d(icds,ibad)
good = ~bad
plt.plot(icds[good],ncts[good])
plt.plot(icds[bad],ncts[bad])
np.median(ncts[good])/np.median(ncts[bad])
# Out:
# 1.488325129370188

# %%
icds,ncts = np.unique(dec.icodesN,return_counts=True)
ibad = [ign for ign,gn in enumerate(dec.gns_names) if 'blank' in gn]
bad = np.in1d(icds,ibad)
good = ~bad
plt.plot(icds[good],ncts[good])
plt.plot(icds[bad],ncts[bad])
np.median(ncts[good])/np.median(ncts[bad])
# Out:
# 3.464539521392313

# %%
def get_inclusive(imols,code_lib):
    iMol,iScore = torch.where(torch.all(imols[...,code_lib]>0,dim=-1))
    return imols[iMol].gather(1,code_lib[iScore])

# %%
viewer = plot_multigenes(dec,genes=['APP','SLC17A7','ATP1B1','PLP1'],colors=['r','g','b','m','c','y','w'],viewer = None,
                         smin=2,smax=30)
# Out:
# WARNING: Traceback (most recent call last):
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#     app.start()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\kernelapp.py", line 725, in start
#     self.io_loop.start()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\tornado\platform\asyncio.py", line 215, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\tornado\ioloop.py", line 740, in _run_callback
#     ret = callback()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\kernelbase.py", line 458, in advance_eventloop
#     eventloop(self)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\eventloops.py", line 128, in loop_qt
#     el.exec() if hasattr(el, 'exec') else el.exec_()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\backends\_qt.py", line 567, in event
#     out = super(QtBaseCanvasBackend, self).event(ev)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\backends\_qt.py", line 532, in mouseMoveEvent
#     self._vispy_mouse_move(
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\base.py", line 216, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 469, in _invoke_callback
#     cb(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\napari\_vispy\canvas.py", line 98, in _process_mouse_event
#     super()._process_mouse_event(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\canvas.py", line 369, in _process_mouse_event
#     getattr(picked.events, event.type)(scene_event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   << caught exception here: >>
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 469, in _invoke_callback
#     cb(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\perspective.py", line 227, in viewbox_mouse_event
#     self._update_rotation(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\arcball.py", line 65, in _update_rotation
#     Quaternion(*_arcball(self._event_value, wh)) *
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\arcball.py", line 101, in _arcball
#     x, y = xy
# ValueError: too many values to unpack (expected 2)
# ERROR: Invoking <bound method Base3DRotationCamera.viewbox_mouse_event of <ArcballCamera at 0x132a5c50fa0>> for SceneMouseEvent
# WARNING: Traceback (most recent call last):
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#     app.start()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\kernelapp.py", line 725, in start
#     self.io_loop.start()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\tornado\platform\asyncio.py", line 215, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\tornado\ioloop.py", line 740, in _run_callback
#     ret = callback()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\kernelbase.py", line 458, in advance_eventloop
#     eventloop(self)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\eventloops.py", line 128, in loop_qt
#     el.exec() if hasattr(el, 'exec') else el.exec_()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\backends\_qt.py", line 567, in event
#     out = super(QtBaseCanvasBackend, self).event(ev)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\backends\_qt.py", line 532, in mouseMoveEvent
#     self._vispy_mouse_move(
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\base.py", line 216, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 469, in _invoke_callback
#     cb(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\napari\_vispy\canvas.py", line 98, in _process_mouse_event
#     super()._process_mouse_event(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\canvas.py", line 369, in _process_mouse_event
#     getattr(picked.events, event.type)(scene_event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   << caught exception here: >>
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 469, in _invoke_callback
#     cb(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\perspective.py", line 227, in viewbox_mouse_event
#     self._update_rotation(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\arcball.py", line 65, in _update_rotation
#     Quaternion(*_arcball(self._event_value, wh)) *
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\arcball.py", line 101, in _arcball
#     x, y = xy
# ValueError: too many values to unpack (expected 2)
# ERROR: Invoking <bound method Base3DRotationCamera.viewbox_mouse_event of <ArcballCamera at 0x132a5c50fa0>> for SceneMouseEvent
# WARNING: Traceback (most recent call last):
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#     app.start()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\kernelapp.py", line 725, in start
#     self.io_loop.start()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\tornado\platform\asyncio.py", line 215, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\tornado\ioloop.py", line 740, in _run_callback
#     ret = callback()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\kernelbase.py", line 458, in advance_eventloop
#     eventloop(self)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\eventloops.py", line 128, in loop_qt
#     el.exec() if hasattr(el, 'exec') else el.exec_()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\backends\_qt.py", line 567, in event
#     out = super(QtBaseCanvasBackend, self).event(ev)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\backends\_qt.py", line 532, in mouseMoveEvent
#     self._vispy_mouse_move(
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\base.py", line 216, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 469, in _invoke_callback
#     cb(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\napari\_vispy\canvas.py", line 98, in _process_mouse_event
#     super()._process_mouse_event(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\canvas.py", line 369, in _process_mouse_event
#     getattr(picked.events, event.type)(scene_event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   << caught exception here: >>
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 469, in _invoke_callback
#     cb(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\perspective.py", line 227, in viewbox_mouse_event
#     self._update_rotation(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\arcball.py", line 65, in _update_rotation
#     Quaternion(*_arcball(self._event_value, wh)) *
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\arcball.py", line 101, in _arcball
#     x, y = xy
# ValueError: too many values to unpack (expected 2)
# ERROR: Invoking <bound method Base3DRotationCamera.viewbox_mouse_event of <ArcballCamera at 0x132a5c50fa0>> for SceneMouseEvent
# WARNING: Traceback (most recent call last):
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#     app.start()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\kernelapp.py", line 725, in start
#     self.io_loop.start()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\tornado\platform\asyncio.py", line 215, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\tornado\ioloop.py", line 740, in _run_callback
#     ret = callback()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\kernelbase.py", line 458, in advance_eventloop
#     eventloop(self)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\eventloops.py", line 128, in loop_qt
#     el.exec() if hasattr(el, 'exec') else el.exec_()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\backends\_qt.py", line 567, in event
#     out = super(QtBaseCanvasBackend, self).event(ev)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\backends\_qt.py", line 532, in mouseMoveEvent
#     self._vispy_mouse_move(
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\base.py", line 216, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 469, in _invoke_callback
#     cb(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\napari\_vispy\canvas.py", line 98, in _process_mouse_event
#     super()._process_mouse_event(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\canvas.py", line 369, in _process_mouse_event
#     getattr(picked.events, event.type)(scene_event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   << caught exception here: >>
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 469, in _invoke_callback
#     cb(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\perspective.py", line 227, in viewbox_mouse_event
#     self._update_rotation(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\arcball.py", line 65, in _update_rotation
#     Quaternion(*_arcball(self._event_value, wh)) *
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\arcball.py", line 101, in _arcball
#     x, y = xy
# ValueError: too many values to unpack (expected 2)
# ERROR: Invoking <bound method Base3DRotationCamera.viewbox_mouse_event of <ArcballCamera at 0x132a5c50fa0>> for SceneMouseEvent
# WARNING: Traceback (most recent call last):
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#     app.start()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\kernelapp.py", line 725, in start
#     self.io_loop.start()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\tornado\platform\asyncio.py", line 215, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\tornado\ioloop.py", line 740, in _run_callback
#     ret = callback()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\kernelbase.py", line 458, in advance_eventloop
#     eventloop(self)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\eventloops.py", line 128, in loop_qt
#     el.exec() if hasattr(el, 'exec') else el.exec_()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\backends\_qt.py", line 567, in event
#     out = super(QtBaseCanvasBackend, self).event(ev)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\backends\_qt.py", line 532, in mouseMoveEvent
#     self._vispy_mouse_move(
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\base.py", line 216, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 469, in _invoke_callback
#     cb(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\napari\_vispy\canvas.py", line 98, in _process_mouse_event
#     super()._process_mouse_event(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\canvas.py", line 369, in _process_mouse_event
#     getattr(picked.events, event.type)(scene_event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   << caught exception here: >>
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 469, in _invoke_callback
#     cb(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\perspective.py", line 227, in viewbox_mouse_event
#     self._update_rotation(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\arcball.py", line 65, in _update_rotation
#     Quaternion(*_arcball(self._event_value, wh)) *
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\arcball.py", line 101, in _arcball
#     x, y = xy
# ValueError: too many values to unpack (expected 2)
# ERROR: Invoking <bound method Base3DRotationCamera.viewbox_mouse_event of <ArcballCamera at 0x132a5c50fa0>> for SceneMouseEvent
# WARNING: Traceback (most recent call last):
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#     app.start()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\kernelapp.py", line 725, in start
#     self.io_loop.start()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\tornado\platform\asyncio.py", line 215, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\tornado\ioloop.py", line 740, in _run_callback
#     ret = callback()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\kernelbase.py", line 458, in advance_eventloop
#     eventloop(self)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\eventloops.py", line 128, in loop_qt
#     el.exec() if hasattr(el, 'exec') else el.exec_()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\backends\_qt.py", line 567, in event
#     out = super(QtBaseCanvasBackend, self).event(ev)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\backends\_qt.py", line 532, in mouseMoveEvent
#     self._vispy_mouse_move(
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\base.py", line 216, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 469, in _invoke_callback
#     cb(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\napari\_vispy\canvas.py", line 98, in _process_mouse_event
#     super()._process_mouse_event(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\canvas.py", line 369, in _process_mouse_event
#     getattr(picked.events, event.type)(scene_event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   << caught exception here: >>
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 469, in _invoke_callback
#     cb(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\perspective.py", line 227, in viewbox_mouse_event
#     self._update_rotation(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\arcball.py", line 65, in _update_rotation
#     Quaternion(*_arcball(self._event_value, wh)) *
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\arcball.py", line 101, in _arcball
#     x, y = xy
# ValueError: too many values to unpack (expected 2)
# ERROR: Invoking <bound method Base3DRotationCamera.viewbox_mouse_event of <ArcballCamera at 0x132a5c50fa0>> for SceneMouseEvent
# WARNING: Traceback (most recent call last):
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#     app.start()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\kernelapp.py", line 725, in start
#     self.io_loop.start()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\tornado\platform\asyncio.py", line 215, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\tornado\ioloop.py", line 740, in _run_callback
#     ret = callback()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\kernelbase.py", line 458, in advance_eventloop
#     eventloop(self)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\eventloops.py", line 128, in loop_qt
#     el.exec() if hasattr(el, 'exec') else el.exec_()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\backends\_qt.py", line 567, in event
#     out = super(QtBaseCanvasBackend, self).event(ev)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\backends\_qt.py", line 532, in mouseMoveEvent
#     self._vispy_mouse_move(
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\base.py", line 216, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 469, in _invoke_callback
#     cb(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\napari\_vispy\canvas.py", line 98, in _process_mouse_event
#     super()._process_mouse_event(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\canvas.py", line 369, in _process_mouse_event
#     getattr(picked.events, event.type)(scene_event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   << caught exception here: >>
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 469, in _invoke_callback
#     cb(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\perspective.py", line 227, in viewbox_mouse_event
#     self._update_rotation(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\arcball.py", line 65, in _update_rotation
#     Quaternion(*_arcball(self._event_value, wh)) *
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\arcball.py", line 101, in _arcball
#     x, y = xy
# ValueError: too many values to unpack (expected 2)
# ERROR: Invoking <bound method Base3DRotationCamera.viewbox_mouse_event of <ArcballCamera at 0x132a5c50fa0>> for SceneMouseEvent
# WARNING: Traceback (most recent call last):
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#     app.start()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\kernelapp.py", line 725, in start
#     self.io_loop.start()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\tornado\platform\asyncio.py", line 215, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\tornado\ioloop.py", line 740, in _run_callback
#     ret = callback()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\kernelbase.py", line 458, in advance_eventloop
#     eventloop(self)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\eventloops.py", line 128, in loop_qt
#     el.exec() if hasattr(el, 'exec') else el.exec_()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\backends\_qt.py", line 567, in event
#     out = super(QtBaseCanvasBackend, self).event(ev)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\backends\_qt.py", line 532, in mouseMoveEvent
#     self._vispy_mouse_move(
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\base.py", line 216, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 469, in _invoke_callback
#     cb(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\napari\_vispy\canvas.py", line 98, in _process_mouse_event
#     super()._process_mouse_event(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\canvas.py", line 369, in _process_mouse_event
#     getattr(picked.events, event.type)(scene_event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   << caught exception here: >>
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 469, in _invoke_callback
#     cb(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\perspective.py", line 227, in viewbox_mouse_event
#     self._update_rotation(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\arcball.py", line 65, in _update_rotation
#     Quaternion(*_arcball(self._event_value, wh)) *
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\arcball.py", line 101, in _arcball
#     x, y = xy
# ValueError: too many values to unpack (expected 2)
# ERROR: Invoking <bound method Base3DRotationCamera.viewbox_mouse_event of <ArcballCamera at 0x132a5c50fa0>> for SceneMouseEvent
# WARNING: Traceback (most recent call last):
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#     app.start()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\kernelapp.py", line 725, in start
#     self.io_loop.start()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\tornado\platform\asyncio.py", line 215, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\tornado\ioloop.py", line 740, in _run_callback
#     ret = callback()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\kernelbase.py", line 458, in advance_eventloop
#     eventloop(self)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\eventloops.py", line 128, in loop_qt
#     el.exec() if hasattr(el, 'exec') else el.exec_()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\backends\_qt.py", line 567, in event
#     out = super(QtBaseCanvasBackend, self).event(ev)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\backends\_qt.py", line 532, in mouseMoveEvent
#     self._vispy_mouse_move(
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\base.py", line 216, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 469, in _invoke_callback
#     cb(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\napari\_vispy\canvas.py", line 98, in _process_mouse_event
#     super()._process_mouse_event(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\canvas.py", line 369, in _process_mouse_event
#     getattr(picked.events, event.type)(scene_event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   << caught exception here: >>
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 469, in _invoke_callback
#     cb(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\perspective.py", line 227, in viewbox_mouse_event
#     self._update_rotation(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\arcball.py", line 65, in _update_rotation
#     Quaternion(*_arcball(self._event_value, wh)) *
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\arcball.py", line 101, in _arcball
#     x, y = xy
# ValueError: too many values to unpack (expected 2)
# ERROR: Invoking <bound method Base3DRotationCamera.viewbox_mouse_event of <ArcballCamera at 0x132a5c50fa0>> for SceneMouseEvent
# WARNING: Traceback (most recent call last):
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#     app.start()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\kernelapp.py", line 725, in start
#     self.io_loop.start()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\tornado\platform\asyncio.py", line 215, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\tornado\ioloop.py", line 740, in _run_callback
#     ret = callback()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\kernelbase.py", line 458, in advance_eventloop
#     eventloop(self)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\eventloops.py", line 128, in loop_qt
#     el.exec() if hasattr(el, 'exec') else el.exec_()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\backends\_qt.py", line 567, in event
#     out = super(QtBaseCanvasBackend, self).event(ev)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\backends\_qt.py", line 532, in mouseMoveEvent
#     self._vispy_mouse_move(
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\base.py", line 216, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 469, in _invoke_callback
#     cb(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\napari\_vispy\canvas.py", line 98, in _process_mouse_event
#     super()._process_mouse_event(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\canvas.py", line 369, in _process_mouse_event
#     getattr(picked.events, event.type)(scene_event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   << caught exception here: >>
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 469, in _invoke_callback
#     cb(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\perspective.py", line 227, in viewbox_mouse_event
#     self._update_rotation(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\arcball.py", line 65, in _update_rotation
#     Quaternion(*_arcball(self._event_value, wh)) *
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\arcball.py", line 101, in _arcball
#     x, y = xy
# ValueError: too many values to unpack (expected 2)
# ERROR: Invoking <bound method Base3DRotationCamera.viewbox_mouse_event of <ArcballCamera at 0x132a5c50fa0>> for SceneMouseEvent
# WARNING: Traceback (most recent call last):
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#     app.start()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\kernelapp.py", line 725, in start
#     self.io_loop.start()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\tornado\platform\asyncio.py", line 215, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\tornado\ioloop.py", line 740, in _run_callback
#     ret = callback()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\kernelbase.py", line 458, in advance_eventloop
#     eventloop(self)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\eventloops.py", line 128, in loop_qt
#     el.exec() if hasattr(el, 'exec') else el.exec_()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\backends\_qt.py", line 567, in event
#     out = super(QtBaseCanvasBackend, self).event(ev)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\backends\_qt.py", line 532, in mouseMoveEvent
#     self._vispy_mouse_move(
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\base.py", line 216, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 469, in _invoke_callback
#     cb(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\napari\_vispy\canvas.py", line 98, in _process_mouse_event
#     super()._process_mouse_event(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\canvas.py", line 369, in _process_mouse_event
#     getattr(picked.events, event.type)(scene_event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   << caught exception here: >>
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 469, in _invoke_callback
#     cb(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\perspective.py", line 227, in viewbox_mouse_event
#     self._update_rotation(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\arcball.py", line 65, in _update_rotation
#     Quaternion(*_arcball(self._event_value, wh)) *
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\arcball.py", line 101, in _arcball
#     x, y = xy
# ValueError: too many values to unpack (expected 2)
# ERROR: Invoking <bound method Base3DRotationCamera.viewbox_mouse_event of <ArcballCamera at 0x132a5c50fa0>> for SceneMouseEvent
# WARNING: Traceback (most recent call last):
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#     app.start()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\kernelapp.py", line 725, in start
#     self.io_loop.start()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\tornado\platform\asyncio.py", line 215, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\tornado\ioloop.py", line 740, in _run_callback
#     ret = callback()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\kernelbase.py", line 458, in advance_eventloop
#     eventloop(self)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\eventloops.py", line 128, in loop_qt
#     el.exec() if hasattr(el, 'exec') else el.exec_()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\backends\_qt.py", line 567, in event
#     out = super(QtBaseCanvasBackend, self).event(ev)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\backends\_qt.py", line 532, in mouseMoveEvent
#     self._vispy_mouse_move(
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\base.py", line 216, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 469, in _invoke_callback
#     cb(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\napari\_vispy\canvas.py", line 98, in _process_mouse_event
#     super()._process_mouse_event(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\canvas.py", line 369, in _process_mouse_event
#     getattr(picked.events, event.type)(scene_event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   << caught exception here: >>
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 469, in _invoke_callback
#     cb(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\perspective.py", line 227, in viewbox_mouse_event
#     self._update_rotation(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\arcball.py", line 65, in _update_rotation
#     Quaternion(*_arcball(self._event_value, wh)) *
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\arcball.py", line 101, in _arcball
#     x, y = xy
# ValueError: too many values to unpack (expected 2)
# ERROR: Invoking <bound method Base3DRotationCamera.viewbox_mouse_event of <ArcballCamera at 0x132a5c50fa0>> for SceneMouseEvent
# ...
# WARNING: Traceback (most recent call last):
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#     app.start()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\kernelapp.py", line 725, in start
#     self.io_loop.start()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\tornado\platform\asyncio.py", line 215, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\tornado\ioloop.py", line 740, in _run_callback
#     ret = callback()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\kernelbase.py", line 458, in advance_eventloop
#     eventloop(self)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\eventloops.py", line 128, in loop_qt
#     el.exec() if hasattr(el, 'exec') else el.exec_()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\backends\_qt.py", line 567, in event
#     out = super(QtBaseCanvasBackend, self).event(ev)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\backends\_qt.py", line 532, in mouseMoveEvent
#     self._vispy_mouse_move(
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\base.py", line 216, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 469, in _invoke_callback
#     cb(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\napari\_vispy\canvas.py", line 98, in _process_mouse_event
#     super()._process_mouse_event(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\canvas.py", line 369, in _process_mouse_event
#     getattr(picked.events, event.type)(scene_event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   << caught exception here: >>
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 469, in _invoke_callback
#     cb(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\perspective.py", line 227, in viewbox_mouse_event
#     self._update_rotation(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\arcball.py", line 65, in _update_rotation
#     Quaternion(*_arcball(self._event_value, wh)) *
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\arcball.py", line 101, in _arcball
#     x, y = xy
# ValueError: too many values to unpack (expected 2)
# ERROR: Invoking <bound method Base3DRotationCamera.viewbox_mouse_event of <ArcballCamera at 0x132a5c50fa0>> for SceneMouseEvent
# WARNING: Traceback (most recent call last):
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#     app.start()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\kernelapp.py", line 725, in start
#     self.io_loop.start()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\tornado\platform\asyncio.py", line 215, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\tornado\ioloop.py", line 740, in _run_callback
#     ret = callback()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\kernelbase.py", line 458, in advance_eventloop
#     eventloop(self)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\eventloops.py", line 128, in loop_qt
#     el.exec() if hasattr(el, 'exec') else el.exec_()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\backends\_qt.py", line 567, in event
#     out = super(QtBaseCanvasBackend, self).event(ev)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\backends\_qt.py", line 532, in mouseMoveEvent
#     self._vispy_mouse_move(
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\base.py", line 216, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 469, in _invoke_callback
#     cb(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\napari\_vispy\canvas.py", line 98, in _process_mouse_event
#     super()._process_mouse_event(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\canvas.py", line 369, in _process_mouse_event
#     getattr(picked.events, event.type)(scene_event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   << caught exception here: >>
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 469, in _invoke_callback
#     cb(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\perspective.py", line 227, in viewbox_mouse_event
#     self._update_rotation(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\arcball.py", line 65, in _update_rotation
#     Quaternion(*_arcball(self._event_value, wh)) *
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\arcball.py", line 101, in _arcball
#     x, y = xy
# ValueError: too many values to unpack (expected 2)
# ERROR: Invoking <bound method Base3DRotationCamera.viewbox_mouse_event of <ArcballCamera at 0x132a5c50fa0>> for SceneMouseEvent
# WARNING: Traceback (most recent call last):
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#     app.start()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\kernelapp.py", line 725, in start
#     self.io_loop.start()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\tornado\platform\asyncio.py", line 215, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\tornado\ioloop.py", line 740, in _run_callback
#     ret = callback()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\kernelbase.py", line 458, in advance_eventloop
#     eventloop(self)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\eventloops.py", line 128, in loop_qt
#     el.exec() if hasattr(el, 'exec') else el.exec_()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\backends\_qt.py", line 567, in event
#     out = super(QtBaseCanvasBackend, self).event(ev)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\backends\_qt.py", line 532, in mouseMoveEvent
#     self._vispy_mouse_move(
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\base.py", line 216, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 469, in _invoke_callback
#     cb(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\napari\_vispy\canvas.py", line 98, in _process_mouse_event
#     super()._process_mouse_event(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\canvas.py", line 369, in _process_mouse_event
#     getattr(picked.events, event.type)(scene_event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   << caught exception here: >>
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 469, in _invoke_callback
#     cb(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\perspective.py", line 227, in viewbox_mouse_event
#     self._update_rotation(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\arcball.py", line 65, in _update_rotation
#     Quaternion(*_arcball(self._event_value, wh)) *
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\arcball.py", line 101, in _arcball
#     x, y = xy
# ValueError: too many values to unpack (expected 2)
# ERROR: Invoking <bound method Base3DRotationCamera.viewbox_mouse_event of <ArcballCamera at 0x132a5c50fa0>> for SceneMouseEvent
# WARNING: Traceback (most recent call last):
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#     app.start()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\kernelapp.py", line 725, in start
#     self.io_loop.start()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\tornado\platform\asyncio.py", line 215, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\tornado\ioloop.py", line 740, in _run_callback
#     ret = callback()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\kernelbase.py", line 458, in advance_eventloop
#     eventloop(self)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\ipykernel\eventloops.py", line 128, in loop_qt
#     el.exec() if hasattr(el, 'exec') else el.exec_()
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\backends\_qt.py", line 567, in event
#     out = super(QtBaseCanvasBackend, self).event(ev)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\backends\_qt.py", line 532, in mouseMoveEvent
#     self._vispy_mouse_move(
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\app\base.py", line 216, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 469, in _invoke_callback
#     cb(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\napari\_vispy\canvas.py", line 98, in _process_mouse_event
#     super()._process_mouse_event(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\canvas.py", line 369, in _process_mouse_event
#     getattr(picked.events, event.type)(scene_event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   << caught exception here: >>
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\util\event.py", line 469, in _invoke_callback
#     cb(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\perspective.py", line 227, in viewbox_mouse_event
#     self._update_rotation(event)
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\arcball.py", line 65, in _update_rotation
#     Quaternion(*_arcball(self._event_value, wh)) *
#   File "C:\Users\BintuLab\anaconda3\envs\cellpose\lib\site-packages\vispy\scene\cameras\arcball.py", line 101, in _arcball
#     x, y = xy
# ValueError: too many values to unpack (expected 2)
# ERROR: Invoking <bound method Base3DRotationCamera.viewbox_mouse_event of <ArcballCamera at 0x132a5c50fa0>> for SceneMouseEvent

# %%
np.array(dec.gns_names)[icds[np.argsort(ncts)[::-1]]]
# Out:
# array(['APP', 'SLC17A7', 'VSNL1', 'TUBB4A', 'ANK2', 'RBFOX1', 'RANGAP1',
#        'ATP1B1', 'SNCB', 'SPOCK1', 'TUBA4A', 'CACNA1A', 'SATB2', 'OLFM3',
#        'SORT1', 'CD81', 'RASGRF2', 'TUBB3', 'PLEC', 'CASP7', 'XPO7',
#        'PAX6', 'PLP1', 'ZNF385D', 'ADGRG1', 'RAN', 'NUP205', 'CACNA1D',
#        'SUN1', 'SLN', 'TAFA2', 'COX7A2L', 'TARDBP', 'TNPO3', 'SPTBN4',
#        'UNC13C', 'SLC32A1', 'blank0132', 'RANBP3', 'STARD13', 'TRPM3',
#        'PLCH1', 'BAD', 'TUBB', 'ATP6AP2', 'CD63', 'CD83', 'RGPD2',
#        'PDE4B', 'TUBG1', 'CACNA1H', 'CASP14', 'PCDH11X', 'ZFPM2', 'NUP54',
#        'PLA2G4C', 'PLPP6', 'PTPRD', 'SLIT2', 'ROBO1', 'APOC1', 'RGPD3',
#        'POM121L2', 'C1QB', 'CASP10', 'AEBP1', 'TMEM132C', 'NUP35',
#        'SH3RF3', 'TUBB2B', 'STK17B', 'THEMIS', 'SPTA1', 'RAE1',
#        'ZNF295-AS1', 'SUN3', 'SUN2', 'PVALB', 'TOR4A', 'TOR1AIP1',
#        'SPTBN2', 'RGPD1', 'TMPO', 'SLC11A1', 'CHAT', 'PTPRK', 'P2RY12',
#        'BRCA2', 'SETD5', 'PDGFD', 'PDGFRA', 'ARL17B', 'ZNF292', 'TAFA1',
#        'TPR', 'SV2C', 'NXF1', 'XPO4', 'TH', 'NUP160', 'PLPP7', 'PLA2G4A',
#        'PRELID2', 'SPTBN5', 'CASP6', 'VPS4B', 'WNT4', 'TNC', 'blank0046',
#        'TYROBP', 'ANLN', 'RMST', 'RGPD5', 'PRKG1', 'SMPD4', 'NXT2',
#        'NUP155', 'RANBP3L', 'PRRT4', 'PPP6R3', 'CASP3', 'TRRAP',
#        'blank0035', 'ATP5G2', 'blank0066', 'TUBA3D', 'CCDC8', 'blank0065',
#        'SHISA9', 'SLC6A16', 'SOX6', 'blank0033', 'blank0100', 'TMEM43',
#        'BAX', 'blank0113', 'SYNE2', 'VIP', 'NUP37', 'CATALASE', 'SORL1',
#        'C9ORF142', 'blank0086', 'C1ORF132', 'MZT2B', 'NUP58', 'PCSK5',
#        'POU6F2', 'blank0008', 'blank0147', 'RIT2', 'PLAAT1', 'SOX11',
#        'TOR3A', 'NUP62', 'PHLDB3', 'PIK3CD', 'SST', 'PLCXD3', 'TOR1AIP2',
#        'SYNE3', 'blank0124', 'blank0104', 'SLC14A1', 'PRPH', 'blank0146',
#        'blank0130', 'blank0131', 'blank0067', 'RYR1', 'NUP42', 'SEMA5A',
#        'SEH1L', 'blank0107', 'ADAMTSL3', 'RTKN2', 'blank0178',
#        'blank0064', 'TSHZ2', 'PTPRT', 'SHISA6', 'blank0151', 'POM121L12',
#        'blank0079', 'blank0040', 'blank0080', 'blank0135', 'blank0181',
#        'blank0043', 'blank0061', 'blank0032', 'blank0182', 'NUTF2',
#        'blank0139', 'UNC13A', 'VCAN', 'blank0115', 'blank0165',
#        'blank0110', 'blank0114', 'PENK', 'NUP98', 'RPRM', 'blank0177',
#        'blank0038', 'blank0167', 'SCN1A', 'blank0186', 'blank0036',
#        'blank0012', 'blank0045', 'blank0152', 'blank0168', 'blank0185',
#        'blank0148', 'blank0161', 'blank0154', 'UNC13B', 'blank0016',
#        'blank0062', 'blank0149', 'blank0158', 'blank0011', 'TMEM170A',
#        'blank0117', 'blank0162', 'blank0019', 'blank0169', 'VWA8',
#        'blank0108', 'blank0116', 'VILL', 'blank0063', 'blank0051',
#        'blank0031', 'blank0160', 'blank0003', 'SCML4', 'blank0150',
#        'blank0073', 'blank0145', 'PACRGL', 'blank0009', 'blank0141',
#        'blank0129', 'CA2', 'blank0075', 'blank0030', 'blank0000', 'CGAS',
#        'blank0074', 'blank0078', 'blank0076', 'SLC6A20', 'CHRM5',
#        'blank0054', 'blank0022', 'P4HA3', 'blank0133', 'APOO',
#        'blank0126', 'blank0004', 'blank0018', 'blank0164', 'blank0029',
#        'blank0027', 'blank0071', 'blank0136', 'blank0134', 'blank0175',
#        'blank0007', 'blank0089', 'blank0142', 'blank0098', 'blank0084',
#        'blank0039', 'blank0093', 'blank0159', 'blank0094', 'blank0096',
#        'blank0052', 'blank0118', 'blank0005', 'blank0163', 'blank0021',
#        'blank0174', 'blank0183', 'RNF219-AS1', 'blank0072', 'blank0024',
#        'blank0047', 'blank0037', 'blank0041', 'blank0002', 'POLDIP3',
#        'blank0092', 'blank0103', 'TUBA3C', 'blank0068', 'blank0023',
#        'blank0156', 'blank0042', 'blank0127', 'blank0125', 'blank0001',
#        'blank0138', 'blank0044', 'blank0034', 'blank0060', 'blank0112',
#        'blank0085', 'blank0137', 'blank0144', 'blank0184', 'blank0050',
#        'blank0028', 'blank0119', 'blank0180', 'blank0097', 'blank0077',
#        'blank0176', 'blank0013', 'blank0172', 'blank0155', 'blank0069',
#        'blank0055', 'PNO1', 'blank0101', 'blank0087', 'blank0143',
#        'blank0017', 'blank0006', 'blank0026', 'blank0140', 'blank0095',
#        'RAP1GAP', 'blank0025', 'blank0056', 'blank0015', 'blank0171',
#        'blank0099', 'blank0058', 'blank0123', 'blank0070', 'blank0091',
#        'blank0173', 'blank0049', 'blank0090', 'blank0048', 'blank0059',
#        'blank0088', 'blank0010', 'blank0020', 'blank0128', 'blank0053',
#        'blank0170', 'blank0105', 'blank0014', 'blank0082', 'ZFPM2-AS1',
#        'blank0121', 'blank0111', 'blank0153', 'blank0179', 'blank0109',
#        'blank0166', 'blank0102', 'blank0081', 'blank0083', 'blank0057',
#        'blank0157', 'blank0106', 'blank0120', 'blank0122'], dtype='<U10')

# %%
# Out:
# 3.37128938955701

# %%
icds,ncts = np.unique(dec.icodesN,return_counts=True)
ibad = [ign for ign,gn in enumerate(dec.gns_names) if 'blank' in gn]
bad = np.in1d(icds,ibad)
good = ~bad
plt.plot(icds[good],ncts[good])
plt.plot(icds[bad],ncts[bad])

# %%
# Out:
# 4.119726527414434

# %%
icds,ncts = np.unique(dec.icodesN,return_counts=True)
plt.plot(icds,ncts)

# %%
dec.XH_pruned
# Out:
# tensor([[[2.0000e+00, 3.9999e+00, 3.9505e+02,  ..., 4.1579e+03,
#           0.0000e+00, 0.0000e+00],
#          [2.8162e+00, 4.0924e+00, 3.9596e+02,  ..., 5.3426e+03,
#           0.0000e+00, 6.0000e+00],
#          [2.0000e+00, 4.2699e+00, 3.9700e+02,  ..., 4.2505e+03,
#           0.0000e+00, 1.0000e+01],
#          [1.9460e+00, 2.9935e+00, 3.9502e+02,  ..., 4.3182e+03,
#           0.0000e+00, 1.2000e+01]],
#
#         [[2.6651e+00, 1.8512e+02, 2.3302e+02,  ..., 6.4310e+03,
#           0.0000e+00, 0.0000e+00],
#          [1.8361e+00, 1.8510e+02, 2.3201e+02,  ..., 4.3202e+03,
#           0.0000e+00, 2.0000e+00],
#          [1.7773e+00, 1.8405e+02, 2.3304e+02,  ..., 5.2613e+03,
#           0.0000e+00, 6.0000e+00],
#          [2.0000e+00, 1.8514e+02, 2.3307e+02,  ..., 4.6356e+03,
#           0.0000e+00, 1.8000e+01]],
#
#         [[2.0000e+00, 3.9918e+02, 2.8014e+02,  ..., 7.8059e+03,
#           0.0000e+00, 0.0000e+00],
#          [1.0000e+00, 4.0014e+02, 2.7911e+02,  ..., 7.2972e+03,
#           0.0000e+00, 2.0000e+00],
#          [2.0000e+00, 4.0102e+02, 2.8073e+02,  ..., 3.9512e+03,
#           0.0000e+00, 1.4000e+01],
#          [2.0000e+00, 4.0029e+02, 2.8010e+02,  ..., 6.2758e+03,
#           0.0000e+00, 1.8000e+01]],
#
#         ...,
#
#         [[3.7131e+01, 2.7370e+03, 2.7970e+03,  ..., 7.5243e+03,
#           1.0000e+00, 9.0000e+00],
#          [3.8139e+01, 2.7351e+03, 2.7980e+03,  ..., 7.3955e+03,
#           1.0000e+00, 1.7000e+01],
#          [3.8060e+01, 2.7362e+03, 2.7970e+03,  ..., 6.8325e+03,
#           1.0000e+00, 1.9000e+01],
#          [3.7026e+01, 2.7362e+03, 2.7979e+03,  ..., 4.3208e+03,
#           1.0000e+00, 2.3000e+01]],
#
#         [[3.8139e+01, 2.6220e+03, 2.7670e+03,  ..., 4.7821e+03,
#           1.0000e+00, 1.7000e+01],
#          [3.8170e+01, 2.6221e+03, 2.7669e+03,  ..., 3.9793e+03,
#           1.0000e+00, 1.9000e+01],
#          [3.8839e+01, 2.6200e+03, 2.7661e+03,  ..., 4.6669e+03,
#           1.0000e+00, 2.1000e+01],
#          [3.8923e+01, 2.6200e+03, 2.7670e+03,  ..., 5.1105e+03,
#           1.0000e+00, 2.3000e+01]],
#
#         [[3.7733e+01, 2.7241e+03, 2.7980e+03,  ..., 1.4284e+04,
#           1.0000e+00, 1.7000e+01],
#          [3.7701e+01, 2.7251e+03, 2.7970e+03,  ..., 1.1850e+04,
#           1.0000e+00, 1.9000e+01],
#          [3.8753e+01, 2.7230e+03, 2.7970e+03,  ..., 7.6641e+03,
#           1.0000e+00, 2.1000e+01],
#          [3.8780e+01, 2.7240e+03, 2.7970e+03,  ..., 9.8348e+03,
#           1.0000e+00, 2.3000e+01]]], dtype=torch.float64)

# %%
dec.icodesN.shape
# Out:
# torch.Size([6783054])

# %%
nbits = 24
codes_lib = torch.from_numpy(np.array(dec.codes__))
codes_lib_01 = torch.zeros([len(codes_lib),nbits],dtype=score_bits.dtype)
for icd,cd in enumerate(codes_lib):
    codes_lib_01[icd,cd]=1

# %%
torch.sum(codes_lib_01,axis=0)
# Out:
# tensor([91., 89., 89., 86., 75., 77., 74., 76., 72., 65., 70., 62., 69., 56.,
#         55., 53., 49., 39., 48., 41., 42., 41., 42., 35.], dtype=torch.float64)

# %%
torch.max(icodes_best)
# Out:
# tensor(32)

# %%
score_bits = dec.score_bits
codes_lib = dec.codes_lib
icodes_best = dec.icodes_best

keep_all_bits = torch.all(score_bits.gather(1,codes_lib[icodes_best])>=0,-1)
torch.sum(keep_all_bits)
# Out:
# tensor(0)

# %%
score_bits[]
# Out:
# tensor([ 1.9563e+04, -1.0000e+00, -1.0000e+00, -1.0000e+00, -1.0000e+00,
#         -1.0000e+00,  1.4897e+04, -1.0000e+00, -1.0000e+00,  1.8152e+04,
#         -1.0000e+00, -1.0000e+00, -1.0000e+00, -1.0000e+00, -1.0000e+00,
#         -1.0000e+00, -1.0000e+00, -1.0000e+00, -1.0000e+00, -1.0000e+00,
#         -1.0000e+00, -1.0000e+00, -1.0000e+00, -1.0000e+00,  9.2767e+03,
#         -1.0000e+00, -1.0000e+00, -1.0000e+00, -1.0000e+00, -1.0000e+00,
#         -1.0000e+00, -1.0000e+00, -1.0000e+00, -1.0000e+00, -1.0000e+00,
#         -1.0000e+00, -1.0000e+00, -1.0000e+00, -1.0000e+00, -1.0000e+00,
#         -1.0000e+00, -1.0000e+00, -1.0000e+00, -1.0000e+00, -1.0000e+00,
#          1.3659e+04, -1.0000e+00, -1.0000e+00], dtype=torch.float64)

# %%
#dec.codes_lib#[dec.icodes_best]
#dec.score_bits

# %%
#dec.icodes_best

# %%
#dec.codes_lib[dec.icodes_best]

# %%
# Out:
# Calculating indexes within cluster...
# Calculating index of molecule...
# Calculating index of first molecule...
# Total time unfolded molecules: 2.615692377090454
# Computing score...
# Total time computing score: 0.13216876983642578
# Computing sorting...
# Total time sorting molecules by score: 4.418367147445679
# Finding best bits per molecules...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[118], line 1
# ----> 1 get_icodes(dec,nmin_bits=4,delta_bits=4,iH=-3,redo=False,norm_brightness=False,nbits=24,is_unique=False)
#
# Cell In[117], line 97, in get_icodes(dec, nmin_bits, delta_bits, iH, redo, norm_brightness, nbits, is_unique)
#      94 Rs_U = Rs[res_unfolder2]
#      96 score_bits = torch.zeros([len(lens),nbits],dtype=scoresF2.dtype)-1
# ---> 97 score_bits[ires,Rs_U]=scoresF2
#     100 codes_lib = torch.from_numpy(np.array(dec.codes__))
#     101 codes_lib_01 = torch.zeros([len(codes_lib),nbits],dtype=score_bits.dtype)
#
# IndexError: index 42 is out of bounds for dimension 1 with size 24

# %%
codes_lib = dec.codes__

# %%
nbits = 48
delta_bits=4
nmin_bits = 4

# %%
import torch

# %%
#np.unique(dec.lens,return_counts=True)

# %%
lens =dec.lens
lens_ = np.repeat(lens, lens)

# %%
# Out:
# 4774205

# %%
res_unfolder = np.load('res_unfolder.npz')['res_unfolder']
lens = np.load('res_unfolder.npz')['lens']
import time
start = time.time()
Mlen = np.max(lens)
print("Calculating indexes within cluster...")
#res_is = np.array([i for l in lens for i in range(l)]) ### could be sped up
res_is = np.tile(np.arange(Mlen), len(lens))
res_is = res_is[res_is < np.repeat(lens, Mlen)]
print("Calculating index of molecule...")
ires = np.repeat(np.arange(len(lens)), lens)
#r0 = np.array([r[0] for r in res for r_ in r])
print("Calculating index of first molecule...")
r0i = np.concatenate([[0],np.cumsum(lens)])[:-1]
r0 = res_unfolder[np.repeat(r0i, lens)]
print("Total time unfolded molecules:",time.time()-start)


import torch
ires = torch.from_numpy(ires.astype(np.int64))
res_unfolder = torch.from_numpy(res_unfolder.astype(np.int64))
res_is = torch.from_numpy(res_is.astype(np.int64))

# %%
def get_inters(self,dinstance_th=2,enforce_color=False):
    """Get an initial intersection of points and save in self.res"""
    res =[]
    if enforce_color:
        icols = self.XH[:,-2].astype(int)
        XH = self.XH
        for icol in tqdm(np.unique(icols)):
            inds = np.where(icols==icol)[0]
            Xs = XH[inds,:3]
            Ts = cKDTree(Xs)
            res_ = Ts.query_ball_tree(Ts,dinstance_th)
            res += [inds[r] for r in res_]
    else:
        XH = self.XH
        Xs = XH[:,:3]
        Ts = cKDTree(Xs)
        res = Ts.query_ball_tree(Ts,dinstance_th)
    self.res = res

# %%
print("Calculating lengths of clusters...")
lens = np.array(list(map(len,res)))
Mlen = np.max(lens)
print("Unfolding indexes...")
res_unfolder = np.concatenate(res)

# %%
def get_icodes(dec,nmin_bits=4,method = 'top4',redo=False,norm_brightness=None,nbits=48,is_unique=True):
    
    ### unfold molecules
    import time
    start = time.time()
    res = dec.res
    print("Filtering to have nmin_bits number of mol/cluster")
    res = [r for r in res if len(r)>=nmin_bits]
    print("Calculating lengths of clusters...")
    lens = np.array(list(map(len,res)))
    Mlen = np.max(lens)
    print("Unfolding indexes...")
    res_unfolder = np.concatenate(res)

    print("Calculating indexes within cluster...")
    #res_is = np.array([i for l in lens for i in range(l)]) ### could be sped up
    res_is = np.tile(np.arange(Mlen), len(lens))
    res_is = res_is[res_is < np.repeat(lens, Mlen)]
    print("Calculating index of molecule...")
    ires = np.repeat(np.arange(len(lens)), lens)
    #r0 = np.array([r[0] for r in res for r_ in r])
    print("Calculating index of first molecule...")
    r0i = np.concatenate([[0],np.cumsum(lens)])[:-1]
    r0 = res_unfolder[np.repeat(r0i, lens)]
    print("Total time unfolded molecules:",time.time()-start)
    
    
    import torch
    ires = torch.from_numpy(ires.astype(np.int64))
    res_unfolder = torch.from_numpy(res_unfolder.astype(np.int64))
    res_is = torch.from_numpy(res_is.astype(np.int64))
